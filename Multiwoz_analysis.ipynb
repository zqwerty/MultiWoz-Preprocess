# %% [markdown]
# ## Multiwoz Analysis
# source: https://www.repository.cam.ac.uk/handle/1810/280608
#
# place this file under the directory.
#
# This file contains:
# - database load and analyse
# - dialog act load and analyse
# - user goal analysis
# - user data annotation

# %%
import numpy as np
import json
from collections import Counter
import pprint
import re

# %% [markdown]
# ### database load and analyse
# load *_db.json, and print attributes

# %%
def read_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)

# %%
database = read_json('restaurant_db.json')

# %%
len(database)
# Out:
# 110

# %%
# domain attributes (*_db.json)
ls = []
attributes = []
for i in database:
    ls.append(len(i))
    attributes.append(tuple(sorted(i.keys())))
print(Counter(ls))
for k,v in dict(Counter(attributes)).items():
    print(k,v)
# print(Counter(attributes))
# Out:
# Counter({11: 77, 10: 17, 12: 16})
# ('address', 'area', 'food', 'id', 'introduction', 'location', 'name', 'phone', 'postcode', 'pricerange', 'type') 77
# ('address', 'area', 'food', 'id', 'introduction', 'location', 'name', 'phone', 'postcode', 'pricerange', 'signature', 'type') 16
# ('address', 'area', 'food', 'id', 'location', 'name', 'phone', 'postcode', 'pricerange', 'type') 14
# ('address', 'area', 'food', 'id', 'introduction', 'location', 'name', 'postcode', 'pricerange', 'type') 3

# %% [markdown]
# ### dialog act load and analyse
# load dialog_acts.json and create dialog_act-slot-values(list)

# %%
# dialog act
dialog_acts = read_json('dialogue_acts.json')

# %%
len(dialog_acts)
# Out:
# 10438

# %%
das = []
da2slot = {}
for item in dialog_acts.values():
    for turn_das in item.values():
        if type(turn_das)==type(""):
            das.append(turn_das)
        else:
            das.extend(turn_das.keys())
            for da,svs in turn_das.items():
                # (da,list of [slot, value])
                if da not in da2slot:
                    da2slot[da] = {}
                for sv in svs:
                    if sv[0] not in da2slot[da]:
                        da2slot[da][sv[0]]=[]
                    da2slot[da][sv[0]].append(sv[1])
da_count = Counter(das)

# %%
# number of sentences that dialog act occurence
da_count
# Out:
# Counter({'Attraction-Inform': 6976,
#          'Attraction-NoOffer': 490,
#          'Attraction-Recommend': 1451,
#          'Attraction-Request': 1641,
#          'Attraction-Select': 438,
#          'Booking-Book': 5256,
#          'Booking-Inform': 5703,
#          'Booking-NoBook': 1313,
#          'Booking-Request': 2708,
#          'Hotel-Inform': 8224,
#          'Hotel-NoOffer': 914,
#          'Hotel-Recommend': 1501,
#          'Hotel-Request': 3215,
#          'Hotel-Select': 1005,
#          'No Annotation': 1933,
#          'Restaurant-Inform': 8071,
#          'Restaurant-NoOffer': 1453,
#          'Restaurant-Recommend': 1495,
#          'Restaurant-Request': 3083,
#          'Restaurant-Select': 918,
#          'Taxi-Inform': 2087,
#          'Taxi-Request': 1613,
#          'Train-Inform': 7204,
#          'Train-NoOffer': 117,
#          'Train-OfferBook': 3032,
#          'Train-OfferBooked': 2309,
#          'Train-Request': 5522,
#          'Train-Select': 389,
#          'general-bye': 9107,
#          'general-greet': 2021,
#          'general-reqmore': 13773,
#          'general-welcome': 4786})

# %%
# slots of specific dialog act
da2slot['Restaurant-Inform'].keys()
# Out:
# dict_keys(['Post', 'Food', 'Name', 'Price', 'Addr', 'Phone', 'Area', 'Choice', 'Ref', 'none'])

# %%
len(da2slot['Hotel-Inform']['Type'])
# Out:
# 2944

# %%
# print all dialog-act-slot and their occurence
for k,v in sorted(da2slot.items()):
    print(k)
    for slot in v.keys():
        print('\t'+slot+'\t'+str(len(da2slot[k][slot])))
# Out:
# Attraction-Inform
# 	Area	2365
# 	Type	2592
# 	Choice	2243
# 	Post	1579
# 	Name	3073
# 	Phone	1742
# 	Addr	2665
# 	Fee	1923
# 	none	28
# 	Price	48
# 	Open	13
# Attraction-NoOffer
# 	Area	324
# 	Type	325
# 	none	109
# 	Name	5
# 	Choice	1
# 	Addr	1
# 	Fee	1
# Attraction-Recommend
# 	Post	165
# 	Name	1461
# 	Area	338
# 	Fee	396
# 	Phone	153
# 	Addr	530
# 	Type	217
# 	Choice	13
# 	none	6
# 	Price	9
# 	Open	3
# Attraction-Request
# 	Area	798
# 	Type	823
# 	Price	86
# 	Name	110
# Attraction-Select
# 	Type	286
# 	none	243
# 	Area	66
# 	Name	57
# 	Fee	47
# 	Choice	7
# 	Phone	1
# 	Price	4
# 	Addr	1
# Booking-Book
# 	Ref	4913
# 	Name	1265
# 	People	789
# 	Time	593
# 	Day	899
# 	Stay	481
# 	none	107
# Booking-Inform
# 	none	5317
# 	Stay	31
# 	Name	277
# 	Day	89
# 	People	71
# 	Ref	18
# 	Time	31
# Booking-NoBook
# 	none	1086
# 	Ref	14
# 	Stay	41
# 	Day	82
# 	People	28
# 	Time	78
# 	Name	72
# Booking-Request
# 	Time	916
# 	Day	1633
# 	People	993
# 	Stay	889
# Hotel-Inform
# 	Name	3678
# 	Ref	50
# 	Type	2944
# 	Choice	3856
# 	Addr	1158
# 	Post	648
# 	Area	2399
# 	Internet	1446
# 	Parking	1373
# 	Stars	1785
# 	none	44
# 	Price	2282
# 	Phone	704
# Hotel-NoOffer
# 	none	322
# 	Type	474
# 	Price	199
# 	Area	225
# 	Stars	203
# 	Internet	29
# 	Parking	33
# 	Name	10
# 	Choice	4
# Hotel-Recommend
# 	Name	1506
# 	Price	319
# 	Area	397
# 	Stars	290
# 	Parking	170
# 	Internet	183
# 	Addr	138
# 	none	15
# 	Type	190
# 	Phone	36
# 	Post	39
# 	Choice	13
# Hotel-Request
# 	Area	1946
# 	Price	1244
# 	Stars	376
# 	Type	252
# 	Parking	251
# 	Internet	191
# 	Name	84
# Hotel-Select
# 	none	513
# 	Price	194
# 	Name	115
# 	Choice	37
# 	Type	388
# 	Area	166
# 	Stars	77
# 	Parking	13
# 	Internet	12
# 	Addr	3
# 	Phone	1
# Restaurant-Inform
# 	Post	1029
# 	Food	3314
# 	Name	4374
# 	Price	2426
# 	Addr	1909
# 	Phone	1412
# 	Area	2864
# 	Choice	3297
# 	Ref	67
# 	none	44
# Restaurant-NoOffer
# 	Food	645
# 	Area	367
# 	none	745
# 	Price	183
# 	Choice	5
# 	Name	5
# Restaurant-Recommend
# 	Area	346
# 	Price	289
# 	Name	1505
# 	Food	373
# 	Addr	251
# 	Phone	69
# 	Choice	18
# 	Post	62
# 	none	13
# Restaurant-Request
# 	Area	1018
# 	Name	56
# 	Price	835
# 	Food	1721
# Restaurant-Select
# 	Food	439
# 	none	481
# 	Area	158
# 	Price	190
# 	Name	166
# 	Choice	23
# 	Addr	5
# Taxi-Inform
# 	Phone	1860
# 	Car	1879
# 	Depart	240
# 	none	51
# 	Dest	196
# 	Leave	190
# 	Arrive	115
# Taxi-Request
# 	Dest	546
# 	Leave	721
# 	Depart	691
# 	Arrive	415
# Train-Inform
# 	Arrive	2955
# 	Id	3103
# 	Leave	3809
# 	Time	941
# 	Dest	1635
# 	Ticket	1177
# 	Depart	1395
# 	Day	952
# 	Choice	2058
# 	Ref	107
# 	People	14
# 	none	28
# Train-NoOffer
# 	none	43
# 	Depart	21
# 	Dest	19
# 	Leave	33
# 	Day	20
# 	Arrive	9
# 	Id	3
# 	Choice	3
# Train-OfferBook
# 	none	2725
# 	Leave	158
# 	Id	180
# 	People	35
# 	Arrive	118
# 	Dest	53
# 	Depart	40
# 	Day	31
# 	Time	8
# 	Ticket	22
# 	Choice	10
# 	Ref	4
# Train-OfferBooked
# 	Ref	2125
# 	Ticket	1369
# 	People	421
# 	Id	474
# 	Leave	249
# 	Depart	120
# 	Dest	114
# 	Time	15
# 	Arrive	146
# 	Day	94
# 	none	40
# 	Choice	4
# Train-Request
# 	Leave	1901
# 	Day	1570
# 	Depart	1573
# 	Dest	1421
# 	Arrive	972
# 	People	591
# Train-Select
# 	none	279
# 	Arrive	40
# 	Leave	91
# 	Id	30
# 	Day	24
# 	Ticket	1
# 	Choice	6
# 	Depart	19
# 	Dest	17
# 	People	4
# general-bye
# 	none	9107
# general-greet
# 	none	2021
# general-reqmore
# 	none	13773
# general-welcome
# 	none	4786

# %% [markdown]
# ### user goal analysis
# load all data and extract user goal, to see all attributes in goal.

# %%
data = read_json('data.json')

# %%
len(data)
# Out:
# 10438

# %%
user_goals = {}
for _,item in data.items():
    goal = item['goal']
    for domain,subgoal in goal.items():
        if domain=='message' or domain=='topic':
            continue
        if domain not in user_goals:
            user_goals[domain] = {}
        for k,v in subgoal.items():
            if type(v)==type({}):
                user_goals[domain][k] = user_goals[domain].setdefault(k,set([]))|set(v.keys())
#                 user_goals[domain].setdefault(k,{}).update(v)
            elif type(v)==type([]):
                user_goals[domain][k] = user_goals[domain].setdefault(k,set([]))|set(v)
#             else:
#                 print(_)
#                 print(k,v,type(v))
#                 print(subgoal)
#         if domain=='hospital' and len(subgoal)>1:
#             print(_)
for domain, subgoal in sorted(user_goals.items()):
    print(domain)
    print(subgoal)
    print()
# Out:
# attraction
# {'info': {'area', 'name', 'type'}, 'reqt': {'area', 'postcode', 'phone', 'address', 'entrance fee', 'type'}, 'fail_info': {'area', 'name', 'type'}}
#
# hospital
# {'info': {'department'}, 'reqt': {'postcode', 'phone', 'address'}, 'fail_info': set()}
#
# hotel
# {'info': {'stars', 'area', 'parking', 'internet', 'pricerange', 'type', 'name'}, 'fail_info': {'stars', 'area', 'parking', 'internet', 'pricerange', 'type', 'name'}, 'book': {'pre_invalid', 'stay', 'day', 'invalid', 'people'}, 'fail_book': {'stay', 'day'}, 'reqt': {'stars', 'area', 'postcode', 'phone', 'parking', 'pricerange', 'internet', 'type', 'address'}}
#
# police
# {'info': set(), 'reqt': {'postcode', 'phone', 'address'}, 'fail_info': set()}
#
# restaurant
# {'info': {'area', 'food', 'name', 'pricerange'}, 'reqt': {'food', 'area', 'postcode', 'phone', 'address', 'pricerange'}, 'fail_info': {'area', 'pricerange', 'name', 'food'}, 'book': {'pre_invalid', 'day', 'time', 'invalid', 'people'}, 'fail_book': {'day', 'time'}}
#
# taxi
# {'info': {'destination', 'arriveBy', 'leaveAt', 'departure'}, 'reqt': {'car type', 'phone'}, 'fail_info': set()}
#
# train
# {'info': {'destination', 'day', 'arriveBy', 'leaveAt', 'departure'}, 'reqt': {'trainID', 'arriveBy', 'price', 'duration', 'leaveAt'}, 'fail_info': set(), 'book': {'invalid', 'people'}, 'fail_book': set()}

# %% [markdown]
# ### Reorganize data
# merge data.json and dialog_acts.json

# %%
sessions_key = list(map(lambda x: x.split('.')[0],data.keys()))
len(sessions_key)
# Out:
# 10438

# %%
dialog_acts[sessions_key[0]]
# Out:
# {'1': {'Hotel-Request': [['Area', '?']]},
#  '2': {'Booking-Inform': [['none', 'none']],
#   'Hotel-Inform': [['Price', 'cheap'], ['Choice', '1'], ['Parking', 'none']]},
#  '3': {'Booking-NoBook': [['Day', 'Tuesday']],
#   'Booking-Request': [['Stay', '?'], ['Day', '?']]},
#  '4': {'Booking-Book': [['Ref', '7GAWK763']],
#   'general-reqmore': [['none', 'none']]},
#  '5': {'general-bye': [['none', 'none']]}}

# %%
data[sessions_key[0]+'.json']
# Out:
# {'goal': {'attraction': {},
#   'hospital': {},
#   'hotel': {'book': {'day': 'tuesday',
#     'invalid': False,
#     'people': '6',
#     'pre_invalid': True,
#     'stay': '2'},
#    'fail_book': {'stay': '3'},
#    'fail_info': {},
#    'info': {'internet': 'yes',
#     'parking': 'yes',
#     'pricerange': 'cheap',
#     'type': 'hotel'}},
#   'message': ["You are looking for a <span class='emphasis'>place to stay</span>. The hotel should be in the <span class='emphasis'>cheap</span> price range and should be in the type of <span class='emphasis'>hotel</span>",
#    "The hotel should <span class='emphasis'>include free parking</span> and should <span class='emphasis'>include free wifi</span>",
#    "Once you find the <span class='emphasis'>hotel</span> you want to book it for <span class='emphasis'>6 people</span> and <span class='emphasis'>3 nights</span> starting from <span class='emphasis'>tuesday</span>",
#    "If the booking fails how about <span class='emphasis'>2 nights</span>",
#    "Make sure you get the <span class='emphasis'>reference number</span>"],
#   'police': {},
#   'restaurant': {},
#   'taxi': {},
#   'topic': {'attraction': False,
#    'booking': False,
#    'general': False,
#    'hospital': False,
#    'hotel': False,
#    'police': False,
#    'restaurant': False,
#    'taxi': False,
#    'train': False},
#   'train': {}},
#  'log': [{'metadata': {},
#    'text': 'am looking for a place to to stay that has cheap price range it should be in a type of hotel'},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'not mentioned',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Okay, do you have a specific area you want to stay in?'},
#   {'metadata': {},
#    'text': "no, i just need to make sure it's cheap. oh, and i need parking"},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'I found 1 cheap hotel for you that includes parking. Do you like me to book it?'},
#   {'metadata': {},
#    'text': 'Yes, please. 6 people 3 nights starting on tuesday.'},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '3'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': "I am sorry but I wasn't able to book that for you for Tuesday. Is there another day you would like to stay or perhaps a shorter stay?"},
#   {'metadata': {}, 'text': 'how about only 2 nights.'},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '2'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Booking was successful.\nReference number is : 7GAWK763. Anything else I can do for you?'},
#   {'metadata': {}, 'text': 'No, that will be all. Good bye.'},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '2'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Thank you for using our services.'}]}

# %%
all_data = {}
for session in sessions_key:
    all_data[session] = data[session+'.json']
    if len(all_data[session]['log'])-len(dialog_acts[session])*2>1:
        # some annotation are incomplete
        all_data.pop(session)
        continue
    for i,turn in enumerate(all_data[session]['log']):
        if i%2==0:
            turn['dialog_act'] = {}
        else:
            turn['dialog_act'] = dialog_acts[session]['%d'%((i+1)/2)]

# %%
# example
all_data[sessions_key[0]]
# Out:
# {'goal': {'attraction': {},
#   'hospital': {},
#   'hotel': {'book': {'day': 'tuesday',
#     'invalid': False,
#     'people': '6',
#     'pre_invalid': True,
#     'stay': '2'},
#    'fail_book': {'stay': '3'},
#    'fail_info': {},
#    'info': {'internet': 'yes',
#     'parking': 'yes',
#     'pricerange': 'cheap',
#     'type': 'hotel'}},
#   'message': ["You are looking for a <span class='emphasis'>place to stay</span>. The hotel should be in the <span class='emphasis'>cheap</span> price range and should be in the type of <span class='emphasis'>hotel</span>",
#    "The hotel should <span class='emphasis'>include free parking</span> and should <span class='emphasis'>include free wifi</span>",
#    "Once you find the <span class='emphasis'>hotel</span> you want to book it for <span class='emphasis'>6 people</span> and <span class='emphasis'>3 nights</span> starting from <span class='emphasis'>tuesday</span>",
#    "If the booking fails how about <span class='emphasis'>2 nights</span>",
#    "Make sure you get the <span class='emphasis'>reference number</span>"],
#   'police': {},
#   'restaurant': {},
#   'taxi': {},
#   'topic': {'attraction': False,
#    'booking': False,
#    'general': False,
#    'hospital': False,
#    'hotel': False,
#    'police': False,
#    'restaurant': False,
#    'taxi': False,
#    'train': False},
#   'train': {}},
#  'log': [{'dialog_act': {},
#    'metadata': {},
#    'text': 'am looking for a place to to stay that has cheap price range it should be in a type of hotel'},
#   {'dialog_act': {'Hotel-Request': [['Area', '?']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'not mentioned',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Okay, do you have a specific area you want to stay in?'},
#   {'dialog_act': {},
#    'metadata': {},
#    'text': "no, i just need to make sure it's cheap. oh, and i need parking"},
#   {'dialog_act': {'Booking-Inform': [['none', 'none']],
#     'Hotel-Inform': [['Price', 'cheap'],
#      ['Choice', '1'],
#      ['Parking', 'none']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'I found 1 cheap hotel for you that includes parking. Do you like me to book it?'},
#   {'dialog_act': {},
#    'metadata': {},
#    'text': 'Yes, please. 6 people 3 nights starting on tuesday.'},
#   {'dialog_act': {'Booking-NoBook': [['Day', 'Tuesday']],
#     'Booking-Request': [['Stay', '?'], ['Day', '?']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '3'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': "I am sorry but I wasn't able to book that for you for Tuesday. Is there another day you would like to stay or perhaps a shorter stay?"},
#   {'dialog_act': {}, 'metadata': {}, 'text': 'how about only 2 nights.'},
#   {'dialog_act': {'Booking-Book': [['Ref', '7GAWK763']],
#     'general-reqmore': [['none', 'none']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '2'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Booking was successful.\nReference number is : 7GAWK763. Anything else I can do for you?'},
#   {'dialog_act': {},
#    'metadata': {},
#    'text': 'No, that will be all. Good bye.'},
#   {'dialog_act': {'general-bye': [['none', 'none']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '2'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Thank you for using our services.'}]}

# %% [markdown]
# ### Automatic annotate user dialog
# - Inform
# - Request
# - General
#
# #### Inform
# Infer from dialog state table change.

# %%
# empty initial state
init_state = {'taxi': {'book': {'booked': []}, 'semi': {'leaveAt': '', 'destination': '', 'departure': '', 'arriveBy': ''}}, 'police': {'book': {'booked': []}, 'semi': {}}, 'restaurant': {'book': {'booked': [], 'time': '', 'day': '', 'people': ''}, 'semi': {'food': '', 'pricerange': '', 'name': '', 'area': ''}}, 'hospital': {'book': {'booked': []}, 'semi': {'department': ''}}, 'hotel': {'book': {'booked': [], 'stay': '', 'day': '', 'people': ''}, 'semi': {'name': '', 'area': '', 'parking': '', 'pricerange': '', 'stars': '', 'internet': '', 'type': ''}}, 'attraction': {'book': {'booked': []}, 'semi': {'type': '', 'name': '', 'area': ''}}, 'train': {'book': {'booked': [], 'people': '', 'ticket': ''}, 'semi': {'leaveAt': '', 'destination': '', 'day': '', 'arriveBy': '', 'departure': ''}}}
init_state
# Out:
# {'attraction': {'book': {'booked': []},
#   'semi': {'area': '', 'name': '', 'type': ''}},
#  'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#  'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#   'semi': {'area': '',
#    'internet': '',
#    'name': '',
#    'parking': '',
#    'pricerange': '',
#    'stars': '',
#    'type': ''}},
#  'police': {'book': {'booked': []}, 'semi': {}},
#  'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#   'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#  'taxi': {'book': {'booked': []},
#   'semi': {'arriveBy': '', 'departure': '', 'destination': '', 'leaveAt': ''}},
#  'train': {'book': {'booked': [], 'people': '', 'ticket': ''},
#   'semi': {'arriveBy': '',
#    'day': '',
#    'departure': '',
#    'destination': '',
#    'leaveAt': ''}}}

# %%
# translate attribute in state table to slot
attribute2slot = {
    'area': 'Area',
    'type': 'Type',
    'name': 'Name',
    'internet': 'Internet',
    'parking': 'Parking',
    'stars': 'Stars',
    'pricerange': 'Price',
    'food': 'Food',
    'arriveBy': 'Arrive',
    'leaveAt': 'Leave',
    'departure': 'Depart',
    'destination': 'Dest',
    'department': 'Department',
    'day': 'Day',
    'people': 'People',
    'stay': 'Stay',
    'time': 'Time',
    'car type': 'Car',
    'phone': 'Phone',
    'postcode': 'Post',
    'address': 'Addr',
    'entrance fee': 'Fee',
    'price': 'Price',
    'duration': 'Duration',
    'trainID': 'TrainID',
    'ref': 'Ref'
}
slot2attribute = {v:k for k,v in attribute2slot.items()}

digit2word = {
    '0': 'zero',
    '1': 'one',
    '2': 'two',
    '3': 'three',
    '4': 'four',
    '5': 'five',
    '6': 'six',
    '7': 'seven',
    '8': 'eight',
    '9': 'nine',
    '10': 'ten'
}
# user da(dict)-slot(set)
user_da_slot = {}
domains = []
for domain, subgoal in user_goals.items():
    domains.append(domain)
    user_da_slot[domain.capitalize()+'-Inform'] = set()
    for slot in subgoal['info']:
        user_da_slot[domain.capitalize()+'-Inform'].add(slot)
    if 'book' in subgoal:
        for slot in subgoal['book']:
            if slot not in ['invalid', 'pre_invalid']:
                user_da_slot[domain.capitalize()+'-Inform'].add(slot)
    
    user_da_slot[domain.capitalize()+'-Request'] = set()
    for slot in subgoal['reqt']:
        user_da_slot[domain.capitalize()+'-Request'].add(slot)
print(domains)
pprint.pprint(user_da_slot)
# Out:
# ['taxi', 'police', 'hospital', 'hotel', 'attraction', 'train', 'restaurant']
# {'Attraction-Inform': {'area', 'name', 'type'},
#  'Attraction-Request': {'address',
#                         'area',
#                         'entrance fee',
#                         'phone',
#                         'postcode',
#                         'type'},
#  'Hospital-Inform': {'department'},
#  'Hospital-Request': {'postcode', 'address', 'phone'},
#  'Hotel-Inform': {'area',
#                   'day',
#                   'internet',
#                   'name',
#                   'parking',
#                   'people',
#                   'pricerange',
#                   'stars',
#                   'stay',
#                   'type'},
#  'Hotel-Request': {'address',
#                    'area',
#                    'internet',
#                    'parking',
#                    'phone',
#                    'postcode',
#                    'pricerange',
#                    'stars',
#                    'type'},
#  'Police-Inform': set(),
#  'Police-Request': {'postcode', 'address', 'phone'},
#  'Restaurant-Inform': {'area',
#                        'day',
#                        'food',
#                        'name',
#                        'people',
#                        'pricerange',
#                        'time'},
#  'Restaurant-Request': {'address',
#                         'area',
#                         'food',
#                         'phone',
#                         'postcode',
#                         'pricerange'},
#  'Taxi-Inform': {'departure', 'leaveAt', 'destination', 'arriveBy'},
#  'Taxi-Request': {'car type', 'phone'},
#  'Train-Inform': {'arriveBy',
#                   'day',
#                   'departure',
#                   'destination',
#                   'leaveAt',
#                   'people'},
#  'Train-Request': {'duration', 'price', 'arriveBy', 'trainID', 'leaveAt'}}

# %%
sample = all_data[sessions_key[0]]
sample
# Out:
# {'goal': {'attraction': {},
#   'hospital': {},
#   'hotel': {'book': {'day': 'tuesday',
#     'invalid': False,
#     'people': '6',
#     'pre_invalid': True,
#     'stay': '2'},
#    'fail_book': {'stay': '3'},
#    'fail_info': {},
#    'info': {'internet': 'yes',
#     'parking': 'yes',
#     'pricerange': 'cheap',
#     'type': 'hotel'}},
#   'message': ["You are looking for a <span class='emphasis'>place to stay</span>. The hotel should be in the <span class='emphasis'>cheap</span> price range and should be in the type of <span class='emphasis'>hotel</span>",
#    "The hotel should <span class='emphasis'>include free parking</span> and should <span class='emphasis'>include free wifi</span>",
#    "Once you find the <span class='emphasis'>hotel</span> you want to book it for <span class='emphasis'>6 people</span> and <span class='emphasis'>3 nights</span> starting from <span class='emphasis'>tuesday</span>",
#    "If the booking fails how about <span class='emphasis'>2 nights</span>",
#    "Make sure you get the <span class='emphasis'>reference number</span>"],
#   'police': {},
#   'restaurant': {},
#   'taxi': {},
#   'topic': {'attraction': False,
#    'booking': False,
#    'general': False,
#    'hospital': False,
#    'hotel': False,
#    'police': False,
#    'restaurant': False,
#    'taxi': False,
#    'train': False},
#   'train': {}},
#  'log': [{'dialog_act': {},
#    'metadata': {},
#    'text': 'am looking for a place to to stay that has cheap price range it should be in a type of hotel'},
#   {'dialog_act': {'Hotel-Request': [['Area', '?']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'not mentioned',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Okay, do you have a specific area you want to stay in?'},
#   {'dialog_act': {},
#    'metadata': {},
#    'text': "no, i just need to make sure it's cheap. oh, and i need parking"},
#   {'dialog_act': {'Booking-Inform': [['none', 'none']],
#     'Hotel-Inform': [['Price', 'cheap'],
#      ['Choice', '1'],
#      ['Parking', 'none']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'I found 1 cheap hotel for you that includes parking. Do you like me to book it?'},
#   {'dialog_act': {},
#    'metadata': {},
#    'text': 'Yes, please. 6 people 3 nights starting on tuesday.'},
#   {'dialog_act': {'Booking-NoBook': [['Day', 'Tuesday']],
#     'Booking-Request': [['Stay', '?'], ['Day', '?']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '3'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': "I am sorry but I wasn't able to book that for you for Tuesday. Is there another day you would like to stay or perhaps a shorter stay?"},
#   {'dialog_act': {}, 'metadata': {}, 'text': 'how about only 2 nights.'},
#   {'dialog_act': {'Booking-Book': [['Ref', '7GAWK763']],
#     'general-reqmore': [['none', 'none']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '2'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Booking was successful.\nReference number is : 7GAWK763. Anything else I can do for you?'},
#   {'dialog_act': {},
#    'metadata': {},
#    'text': 'No, that will be all. Good bye.'},
#   {'dialog_act': {'general-bye': [['none', 'none']]},
#    'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '2'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Thank you for using our services.'}]}

# %%
def dict_diff(dict1,dict2):
    # compare two dict
    # two exceptions:
    # 1) 'bus' domain unuse
    # 2) 'ticket' and 'people' attr for 'train-book' domain may be missing
    diff_dict = {}
    for k,v2 in dict2.items():
        if k in dict1:
            assert type(v2)==type(dict1[k])
            v1 = dict1[k]
            if v1 != v2:
                if type(v2) != type({}):
                    diff_dict[k] = v2
                else:
                    if dict_diff(v1,v2)!={}:
                        diff_dict[k] = dict_diff(v1,v2)
        else:
            if k!='bus':
                assert k=='people'
                # people attribute for train domain
                if v2!='':
                    diff_dict[k] = v2
    return diff_dict

# %%
da2usersen = {}
cnt0 = 0
cnt1 = 0
cnt2 = 0
cnt3 = 0
cnt4 = 0
for no,session in all_data.items():
    usersen = [session['log'][i]['text'] for i in range(0,len(session['log'])-1,2)]
    
    user_das = []
    user_goal = session['goal']
    for i in range(1,len(session['log']),2):
        prev_state = init_state if i==1 else session['log'][i-2]['metadata']
        next_state = session['log'][i]['metadata']
        prev_utterance = '' if i==1 else session['log'][i-2]['text']
        next_utterance = session['log'][i]['text']
        user_utterance = session['log'][i-1]['text']
        if i==1 or 'dialog_act' not in session['log'][i-2]:
            prev_da = {}
        else:
            prev_da = session['log'][i-2]['dialog_act']
        next_da = session['log'][i]['dialog_act']
        diff_table = dict_diff(prev_state, next_state)
        
        # user da annotate, Inform
        da = {}
        for domain in domains:
            if len(user_goal[domain])!=0:
                da[domain.capitalize()+'-Inform'] = []
                for slot in user_da_slot[domain.capitalize()+'-Inform']:
                    value_state = ''
                    if domain in diff_table:
                        for subtable in diff_table[domain].values():
                            if slot in subtable and subtable[slot] != 'not mentioned':
                                value_state = subtable[slot]                    
                    # state for that slot change
                    
                    value_goal = ''
                    if slot in user_goal[domain]['info']:
                        value_goal = user_goal[domain]['info'][slot]
                    elif 'book' in user_goal[domain] and slot in user_goal[domain]['book']:
                        value_goal = user_goal[domain]['book'][slot]
                    # slot-value appear in goal
                    
                    if value_state!='':
                        # state change
                        if value_state.lower() in user_utterance.lower():
                            # value in user utterance
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif slot.lower() in user_utterance.lower():
                            # slot in user utterance
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif slot=='people' and 'one person' in user_utterance.lower():
                            # keyword 'person' for people
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],"1"])
                        elif slot=='stay' and 'night' in user_utterance.lower():
                            # keyword 'night' for stay
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif slot=='internet' and 'wifi' in user_utterance.lower():
                            # alias 'wifi' for internet
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif slot=='pricerange' and 'price' in user_utterance.lower():
                            # alias 'price' for pricerange
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif slot=='arriveBy' and 'arrive' in user_utterance.lower():
                            # alias 'arrive' for arriveBy
                            if value_state == value_goal:
                                da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif slot=='leaveAt' and 'leave' in user_utterance.lower():
                            # alias 'leave' for leaveAt
                            if value_state != value_goal:
                                da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif slot=='name' and (value_state.lower() in prev_utterance.lower()):
                            # coreference
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif domain.capitalize()+'-Request' in prev_da and [attribute2slot[slot],'?'] in prev_da[domain.capitalize()+'-Request']:
                            # answer system request
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif value_goal!='' and value_goal.lower() in user_utterance.lower():
                            # wrong state update
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                        elif value_state in digit2word and (' '+digit2word[value_state]) in user_utterance.lower():
                            # alias for digital value
                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_state])
                    elif value_goal!='':
                        # state don't change but value is in goal
                        if value_goal=='yes' or value_goal=='no':
                            # binary value
                            if '?' not in user_utterance:
                                # not for acknowledgement
                                if slot.lower() in user_utterance.lower():
                                    da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                                elif slot=='internet' and 'wifi' in user_utterance.lower():
                                    da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                        elif value_goal.isdigit():
                            # digital value
                            if (' '+value_goal.lower()+' ') in user_utterance.lower() or (' '+digit2word[value_goal]) in user_utterance.lower():
                                if slot=='stars':
                                    if 'stars' in user_utterance.lower():
                                        da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                                    elif 'star' in user_utterance.lower() and 'start' not in user_utterance.lower():
                                        da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                                elif slot=='stay':
                                    if 'stay' in user_utterance.lower():
                                        da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                                    elif 'night' in user_utterance.lower():
                                        da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                                elif slot=='people':
                                    if 'people' in user_utterance.lower() or 'person' in user_utterance.lower():
                                        if domain in user_utterance.lower() or domain in prev_utterance.lower():
                                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                                    elif 'ticket' in user_utterance.lower():
                                        if domain=='train':
                                            da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                                else:
                                    assert 0
                        elif value_goal in user_utterance.lower():
                            # string value
                            if domain in user_utterance.lower() or domain in prev_utterance.lower():
                                da[domain.capitalize()+'-Inform'].append([attribute2slot[slot],value_goal])
                    
                if len(da[domain.capitalize()+'-Inform'])==0:
                    da.pop(domain.capitalize()+'-Inform')

        # Request
        for domain in domains:
            if len(user_goal[domain])!=0:
                da[domain.capitalize()+'-Request'] = []
                slots = user_da_slot[domain.capitalize()+'-Request']
                for slot in slots:
                    # for each possible request in goal
                    if 'reqt' in user_goal[domain] and slot in user_goal[domain]['reqt']:
                        # if actually in request goal
                        if slot.lower() in user_utterance:
                            da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])                              
                        elif slot=='internet' and 'wifi' in user_utterance.lower():
                            da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
                        elif slot=='postcode' and 'post' in user_utterance.lower():
                            da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
                        elif slot=='pricerange' and 'price' in user_utterance.lower():
                            da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
                        elif slot=='trainID' and ' id' in user_utterance.lower():
                            da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
                        elif slot=='arriveBy' and 'arrive' in user_utterance.lower():
                            if 'when' in user_utterance.lower() or 'what time' in user_utterance.lower():
                                da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
                        elif slot=='leaveAt' and 'leave' in user_utterance.lower():
                            if 'when' in user_utterance.lower() or 'what time' in user_utterance.lower():
                                da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
                        elif slot=='duration' and 'travel time' in user_utterance.lower():
                            da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
                        elif slot=='arriveBy' and 'arrival time' in user_utterance.lower():
                            da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
                        elif slot=='leaveAt' and 'departure time' in user_utterance.lower():
                            da[domain.capitalize()+'-Request'].append([attribute2slot[slot],'?'])
#                             print(user_utterance)
                
                # for request not in goal
                if ' ref' in user_utterance.lower():
                    if 'book' in user_goal[domain] and len(user_goal[domain]['book'])>0:
                        da[domain.capitalize()+'-Request'].append(['Ref','?'])

                        
                if len(da[domain.capitalize()+'-Request'])==0:
                    da.pop(domain.capitalize()+'-Request')
                                
        # Clarify the domain of request slot (for address, postcode, area, phone,...)
        slot2domain = {}
#         print(user_utterance)
        for domain_da, svs in da.items():
            if 'Request' in domain_da:
                for (s,v) in svs:
                    slot2domain.setdefault(s,[])
                    slot2domain[s].append(domain_da.split('-')[0])
#         print(slot2domain)
        for s,d in slot2domain.items():
            if len(d)>1:
                # several request for same slot
                # note that in data no slot alias appear twice
                if len(re.findall(s, user_utterance))<=1:
                    # for slot don't appear twice
                    system_ack = []
                    for each in d:
                        if each+'-Inform' in next_da:
                            if s in map(lambda x:x[0],next_da[each+'-Inform']):
                                # system Inform the value of slot:
                                system_ack.append(each)
                        elif each+'-Recommend' in next_da:
                            if s in map(lambda x:x[0],next_da[each+'-Recommend']):
                                # system Recommend the value of slot:
                                system_ack.append(each)
                            
                    if len(system_ack)==0:
                        # not informed or recommended by system, abort. 227 samples
                        for each in d:
                            for request_slot_value in da[each+'-Request']:
                                if s==request_slot_value[0]:
                                    da[each+'-Request'].remove(request_slot_value)
                            if len(da[each+'-Request'])==0:
                                da.pop(each+'-Request')
                    elif len(system_ack)==1:
                        # one of domain informed or recommended by system. 1441 samples
                        for each in d:
                            if each in system_ack:
                                continue
                            for request_slot_value in da[each+'-Request']:
                                if s==request_slot_value[0]:
                                    da[each+'-Request'].remove(request_slot_value)
                            if len(da[each+'-Request'])==0:
                                da.pop(each+'-Request')
                    elif len(system_ack)==2:
                        # two of domain informed or recommended by system. 3 samples
                        pass
                    else:
                        # no >2 sample
                        assert 0
                        
        # General
        if len(da)==0:
            for domain in domains:
                if domain in user_utterance.lower():
                    da.setdefault(domain.capitalize()+'-Inform',[])
                    da[domain.capitalize()+'-Inform'].append(['none','none'])
#                     cnt3+=1
        if len(da)==0:
            if 'bye' in user_utterance.lower():
#                 cnt0+=1
                da['general-bye'] = [['none','none']]
#                 print(user_utterance)
            elif 'thank' in user_utterance.lower():
#                 cnt1+=1
                da['general-thank'] = [['none','none']]
#                 print(user_utterance)
            elif sum([1 if x in user_utterance.lower() else 0 for x in ['hello','hi ']])>0:
#                 cnt2+=1
                da['general-greet'] = [['none','none']]
#                 print(user_utterance)
            
        
        user_das.append(da)
        
        if len(da)==0:
            cnt3+=1
#             print(user_utterance)
        else:
            cnt4+=1
        
#         if no=='PMUL1635':
#             print(user_utterance)
#             print(da)
#             print(next_da)
#             print(diff_table)
    
    assert len(usersen) == len(user_das)
    for j,user_da in enumerate(user_das):
        session['log'][j*2]['dialog_act'] = user_das[j]
    for da,sen in zip(user_das,usersen):
        da2usersen.setdefault(tuple(da),[])
        da2usersen[tuple(da)].append(sen)
print(cnt0,cnt1,cnt2,cnt3,cnt4)
# Out:
# 0 0 0 7091 64396

# %%
8068+63419
# Out:
# 71487

# %%
# da statistics
cnt = [0]*10
user_da2slot2val = {}
sys_da2slot2val = {}
for no,session in all_data.items():
    for i in range(0,len(session['log']),2):
        user_da = session['log'][i]['dialog_act']
        for da,svs in user_da.items():
            user_da2slot2val.setdefault(da,{})
            for s,v in svs:
                user_da2slot2val[da].setdefault(s,[])
                user_da2slot2val[da][s].append(v)
    for i in range(1,len(session['log']),2):
        sys_da = session['log'][i]['dialog_act']
        if type(sys_da)!=type({}):
            assert sys_da=='No Annotation'
            session['log'][i]['dialog_act'] = {}
            continue
        for da,svs in sys_da.items():
            sys_da2slot2val.setdefault(da,{})
            for s,v in svs:
                sys_da2slot2val[da].setdefault(s,[])
                sys_da2slot2val[da][s].append(v)
print('User Dialog Act:')
for k,v in sorted(user_da2slot2val.items()):
    print(k)
    for s in sorted(v.keys()):
        print('\t',len(v[s]),'\t',s)
print()
print('System Dialog Act:')
for k,v in sorted(sys_da2slot2val.items()):
    print(k)
    for s in sorted(v.keys()):
        print('\t',len(v[s]),'\t',s)
# Out:
# User Dialog Act:
# Attraction-Inform
# 	 2084 	 Area
# 	 1447 	 Name
# 	 2477 	 Type
# 	 269 	 none
# Attraction-Request
# 	 1236 	 Addr
# 	 379 	 Area
# 	 1109 	 Fee
# 	 1314 	 Phone
# 	 1401 	 Post
# 	 258 	 Type
# Hospital-Inform
# 	 95 	 Department
# 	 231 	 none
# Hospital-Request
# 	 101 	 Addr
# 	 123 	 Phone
# 	 150 	 Post
# Hotel-Inform
# 	 2241 	 Area
# 	 2513 	 Day
# 	 1808 	 Internet
# 	 1996 	 Name
# 	 1894 	 Parking
# 	 2373 	 People
# 	 2375 	 Price
# 	 2335 	 Stars
# 	 3161 	 Stay
# 	 2731 	 Type
# 	 642 	 none
# Hotel-Request
# 	 518 	 Addr
# 	 190 	 Area
# 	 235 	 Internet
# 	 228 	 Parking
# 	 478 	 Phone
# 	 511 	 Post
# 	 243 	 Price
# 	 453 	 Ref
# 	 61 	 Stars
# 	 141 	 Type
# Police-Inform
# 	 161 	 none
# Police-Request
# 	 101 	 Addr
# 	 53 	 Phone
# 	 95 	 Post
# Restaurant-Inform
# 	 3225 	 Area
# 	 2582 	 Day
# 	 4661 	 Food
# 	 1790 	 Name
# 	 2489 	 People
# 	 3434 	 Price
# 	 3007 	 Time
# 	 855 	 none
# Restaurant-Request
# 	 1178 	 Addr
# 	 153 	 Area
# 	 138 	 Food
# 	 1156 	 Phone
# 	 832 	 Post
# 	 186 	 Price
# 	 515 	 Ref
# Taxi-Inform
# 	 638 	 Arrive
# 	 887 	 Depart
# 	 831 	 Dest
# 	 940 	 Leave
# 	 889 	 none
# Taxi-Request
# 	 378 	 Car
# 	 50 	 Phone
# Train-Inform
# 	 2150 	 Arrive
# 	 3963 	 Day
# 	 3846 	 Depart
# 	 4041 	 Dest
# 	 1907 	 Leave
# 	 2115 	 People
# 	 558 	 none
# Train-Request
# 	 296 	 Arrive
# 	 762 	 Duration
# 	 293 	 Leave
# 	 944 	 Price
# 	 607 	 Ref
# 	 465 	 TrainID
# general-bye
# 	 2714 	 none
# general-greet
# 	 45 	 none
# general-thank
# 	 9026 	 none
#
# System Dialog Act:
# Attraction-Inform
# 	 2664 	 Addr
# 	 2365 	 Area
# 	 2241 	 Choice
# 	 1922 	 Fee
# 	 3072 	 Name
# 	 13 	 Open
# 	 1741 	 Phone
# 	 1579 	 Post
# 	 48 	 Price
# 	 2589 	 Type
# 	 28 	 none
# Attraction-NoOffer
# 	 1 	 Addr
# 	 324 	 Area
# 	 1 	 Choice
# 	 1 	 Fee
# 	 5 	 Name
# 	 325 	 Type
# 	 109 	 none
# Attraction-Recommend
# 	 530 	 Addr
# 	 338 	 Area
# 	 13 	 Choice
# 	 396 	 Fee
# 	 1461 	 Name
# 	 3 	 Open
# 	 153 	 Phone
# 	 165 	 Post
# 	 9 	 Price
# 	 217 	 Type
# 	 6 	 none
# Attraction-Request
# 	 797 	 Area
# 	 110 	 Name
# 	 86 	 Price
# 	 823 	 Type
# Attraction-Select
# 	 1 	 Addr
# 	 66 	 Area
# 	 7 	 Choice
# 	 47 	 Fee
# 	 57 	 Name
# 	 1 	 Phone
# 	 4 	 Price
# 	 286 	 Type
# 	 243 	 none
# Booking-Book
# 	 898 	 Day
# 	 1263 	 Name
# 	 788 	 People
# 	 4910 	 Ref
# 	 480 	 Stay
# 	 593 	 Time
# 	 107 	 none
# Booking-Inform
# 	 89 	 Day
# 	 277 	 Name
# 	 71 	 People
# 	 18 	 Ref
# 	 31 	 Stay
# 	 31 	 Time
# 	 5315 	 none
# Booking-NoBook
# 	 82 	 Day
# 	 72 	 Name
# 	 28 	 People
# 	 14 	 Ref
# 	 41 	 Stay
# 	 78 	 Time
# 	 1086 	 none
# Booking-Request
# 	 1633 	 Day
# 	 993 	 People
# 	 889 	 Stay
# 	 916 	 Time
# Hotel-Inform
# 	 1158 	 Addr
# 	 2398 	 Area
# 	 3855 	 Choice
# 	 1446 	 Internet
# 	 3677 	 Name
# 	 1373 	 Parking
# 	 704 	 Phone
# 	 648 	 Post
# 	 2282 	 Price
# 	 50 	 Ref
# 	 1784 	 Stars
# 	 2943 	 Type
# 	 44 	 none
# Hotel-NoOffer
# 	 225 	 Area
# 	 4 	 Choice
# 	 29 	 Internet
# 	 10 	 Name
# 	 33 	 Parking
# 	 199 	 Price
# 	 203 	 Stars
# 	 474 	 Type
# 	 322 	 none
# Hotel-Recommend
# 	 138 	 Addr
# 	 397 	 Area
# 	 13 	 Choice
# 	 183 	 Internet
# 	 1506 	 Name
# 	 170 	 Parking
# 	 36 	 Phone
# 	 39 	 Post
# 	 319 	 Price
# 	 290 	 Stars
# 	 190 	 Type
# 	 15 	 none
# Hotel-Request
# 	 1946 	 Area
# 	 191 	 Internet
# 	 84 	 Name
# 	 251 	 Parking
# 	 1243 	 Price
# 	 375 	 Stars
# 	 252 	 Type
# Hotel-Select
# 	 3 	 Addr
# 	 166 	 Area
# 	 37 	 Choice
# 	 12 	 Internet
# 	 115 	 Name
# 	 13 	 Parking
# 	 1 	 Phone
# 	 194 	 Price
# 	 77 	 Stars
# 	 388 	 Type
# 	 513 	 none
# Restaurant-Inform
# 	 1908 	 Addr
# 	 2864 	 Area
# 	 3294 	 Choice
# 	 3313 	 Food
# 	 4372 	 Name
# 	 1412 	 Phone
# 	 1028 	 Post
# 	 2424 	 Price
# 	 67 	 Ref
# 	 44 	 none
# Restaurant-NoOffer
# 	 366 	 Area
# 	 5 	 Choice
# 	 644 	 Food
# 	 5 	 Name
# 	 183 	 Price
# 	 745 	 none
# Restaurant-Recommend
# 	 251 	 Addr
# 	 346 	 Area
# 	 18 	 Choice
# 	 373 	 Food
# 	 1505 	 Name
# 	 69 	 Phone
# 	 62 	 Post
# 	 289 	 Price
# 	 13 	 none
# Restaurant-Request
# 	 1018 	 Area
# 	 1717 	 Food
# 	 56 	 Name
# 	 834 	 Price
# Restaurant-Select
# 	 5 	 Addr
# 	 158 	 Area
# 	 23 	 Choice
# 	 439 	 Food
# 	 165 	 Name
# 	 190 	 Price
# 	 481 	 none
# Taxi-Inform
# 	 115 	 Arrive
# 	 1879 	 Car
# 	 240 	 Depart
# 	 196 	 Dest
# 	 190 	 Leave
# 	 1860 	 Phone
# 	 51 	 none
# Taxi-Request
# 	 415 	 Arrive
# 	 691 	 Depart
# 	 546 	 Dest
# 	 721 	 Leave
# Train-Inform
# 	 2954 	 Arrive
# 	 2058 	 Choice
# 	 952 	 Day
# 	 1395 	 Depart
# 	 1635 	 Dest
# 	 3102 	 Id
# 	 3809 	 Leave
# 	 14 	 People
# 	 107 	 Ref
# 	 1177 	 Ticket
# 	 941 	 Time
# 	 28 	 none
# Train-NoOffer
# 	 9 	 Arrive
# 	 3 	 Choice
# 	 20 	 Day
# 	 21 	 Depart
# 	 19 	 Dest
# 	 3 	 Id
# 	 33 	 Leave
# 	 43 	 none
# Train-OfferBook
# 	 118 	 Arrive
# 	 10 	 Choice
# 	 31 	 Day
# 	 40 	 Depart
# 	 53 	 Dest
# 	 180 	 Id
# 	 158 	 Leave
# 	 35 	 People
# 	 4 	 Ref
# 	 22 	 Ticket
# 	 8 	 Time
# 	 2725 	 none
# Train-OfferBooked
# 	 146 	 Arrive
# 	 4 	 Choice
# 	 94 	 Day
# 	 120 	 Depart
# 	 114 	 Dest
# 	 474 	 Id
# 	 249 	 Leave
# 	 421 	 People
# 	 2124 	 Ref
# 	 1368 	 Ticket
# 	 15 	 Time
# 	 40 	 none
# Train-Request
# 	 971 	 Arrive
# 	 1570 	 Day
# 	 1572 	 Depart
# 	 1421 	 Dest
# 	 1901 	 Leave
# 	 591 	 People
# Train-Select
# 	 40 	 Arrive
# 	 6 	 Choice
# 	 24 	 Day
# 	 19 	 Depart
# 	 17 	 Dest
# 	 30 	 Id
# 	 91 	 Leave
# 	 4 	 People
# 	 1 	 Ticket
# 	 279 	 none
# general-bye
# 	 9105 	 none
# general-greet
# 	 2021 	 none
# general-reqmore
# 	 13769 	 none
# general-welcome
# 	 4785 	 none

# %%
# span annotate
cnt = [0]*10
span_da = {}
no_span_sentence = []
for no,session in all_data.items():
    for i in range(0,len(session['log']),1):
        user_da = session['log'][i]['dialog_act']
        user_utterance = session['log'][i]['text']
        span_info = []
        for da,svs in user_da.items():
            if 'Inform' in da:
                span_da.setdefault(da,{})
                for s,v in svs:
                    if s!='Internet' and s!='Parking' and s!='none':
                        cnt[-1]+=1
                        is_annotated = False
                        span_da[da].setdefault(s,set([]))
                        span_da[da][s].add(v)
                        if v.lower() in user_utterance.lower():
                            # mentioned explicitly
                            cnt[0]+=1
                            is_annotated = True
                            char_index_begin = user_utterance.lower().index(v.lower())
                            char_index_end = char_index_begin+len(v)
                            word_index_begin = len(user_utterance[:char_index_begin].split())
                            word_index_end = len(user_utterance[:char_index_end].split())-1
                            span_info.append((da,s,v,word_index_begin,word_index_end))
                        elif v in digit2word and digit2word[v] in user_utterance.lower():
                            # digit alias
                            cnt[1]+=1
                            is_annotated = True
                            char_index_begin = user_utterance.lower().index(digit2word[v].lower())
                            char_index_end = char_index_begin+len(digit2word[v])
                            word_index_begin = len(user_utterance[:char_index_begin].split())
                            word_index_end = len(user_utterance[:char_index_end].split())-1
                            span_info.append((da,s,v,word_index_begin,word_index_end))
                        elif s=='Name':
                            # coreference
                            cnt[2]+=1
                        elif 'same' in user_utterance.lower() and s.lower() in user_utterance.lower():
                            # coreference-'same'
                            if 'same '+s.lower() in user_utterance.lower():
                                cnt[3]+=1
                                is_annotated = True
                                assert len(s.split())==1
                                char_index_begin = user_utterance.lower().index('same '+s.lower())
                                char_index_end = char_index_begin+len('same '+s.lower())
                                word_index_begin = len(user_utterance[:char_index_begin].split())
                                word_index_end = len(user_utterance[:char_index_end].split())-1
                                span_info.append((da,s,v,word_index_begin,word_index_end))
                            elif s=='People':
                                cnt[3]+=1
                                is_annotated = True
                                if  'same group of people' in user_utterance.lower():
                                    pattern = 'same group of people'
                                elif 'same number of people' in user_utterance.lower():
                                    pattern = 'same number of people'
                                elif 'same amount of people' in user_utterance.lower():
                                    pattern = 'same amount of people'
                                elif 'same quantity of people' in user_utterance.lower():
                                    pattern = 'same quantity of people'
                                else:
                                    assert 0
                                char_index_begin = user_utterance.lower().index(pattern)
                                word_index_begin = len(user_utterance[:char_index_begin].split())
                                span_info.append((da,s,v,word_index_begin,word_index_begin+3))
                            else:
                                char_index_begin = user_utterance.lower().index('same')
                                word_index_begin = len(user_utterance[:char_index_begin].split())
                                shift = len(user_utterance[:user_utterance.lower().index(s.lower())].split())-word_index_begin
                                if 0<shift<=3:
                                    cnt[3]+=1
                                    is_annotated = True
                                    span_info.append((da,s,v,word_index_begin,word_index_begin+shift))
                            
                        elif 'care' in v:
                            # value: don't care 
                            key_phrases = ["not particular", "no particular", "any ","not really", "don't matter", "don't care", "do not care", "don't really care", "dont care", "doesn't matter", "doesnt matter", "don't have a preference", "do not have a preference", "doesn't really matter", "does not matter"]
                            flag = 0
                            for key_phrase in key_phrases:
                                if key_phrase in user_utterance.lower():
                                    flag=1
                                    break
                            if flag==1:
                                char_index_begin = user_utterance.lower().index(key_phrase)
                                word_index_begin = len(user_utterance[:char_index_begin].split())
                                span_info.append((da,s,v,word_index_begin,word_index_begin+len(key_phrase.split())-1))
                                cnt[4]+=1
                                is_annotated = True
                        elif ':' in v and ':' in user_utterance.lower():
                            # time value
                            char_index_begin = user_utterance.lower().index(':')
                            word_index_begin = len(user_utterance[:char_index_begin].split())-1
                            if user_utterance.split()[word_index_begin-1]=='after' or user_utterance.split()[word_index_begin-1]=='before':
                                span_info.append((da,s,v,word_index_begin-1,word_index_begin))
                            else:
                                span_info.append((da,s,v,word_index_begin,word_index_begin))
                            cnt[5]+=1
                            is_annotated = True
                        elif v=='centre' and 'center' in user_utterance.lower():
                            char_index_begin = user_utterance.lower().index('center')
                            word_index_begin = len(user_utterance[:char_index_begin].split())
                            span_info.append((da,s,v,word_index_begin,word_index_begin))
                            cnt[6]+=1
                            is_annotated = True
                        else:
                            cnt[7]+=1
                        if is_annotated:
                            cnt[-2]+=1
                        else:
                            no_span_sentence.append((da,s,v,user_utterance))
        session['log'][i]['span_info'] = span_info
print(cnt)
# Out:
# [142535, 1428, 2525, 1002, 285, 358, 57, 1538, 145665, 149890]

# %%
no_span_sentence
# Out:
# [('Hotel-Inform',
#   'Price',
#   'dont care',
#   'no, but it should have free parking, please.'),
#  ('Restaurant-Inform',
#   'Name',
#   'meze bar restaurant',
#   'Can I have the phone number, address and postcode for the restaurant please?'),
#  ('Attraction-Inform',
#   'Name',
#   'funky fun house',
#   'Could i also get the phone number and postcode?'),
#  ('Attraction-Inform',
#   'Name',
#   "christ's college",
#   'Can I please get their phone number and postcode? '),
#  ('Restaurant-Inform',
#   'Name',
#   'the good luck chinese food takeaway',
#   'Yes, that sounds good! Book a table for 3 at 13:45 please. '),
#  ('Train-Inform', 'Dest', 'cambridge', 'I will be heading to cabridge'),
#  ('Attraction-Inform',
#   'Name',
#   'the cherry hinton village centre',
#   'I would like to get the phone number, please.'),
#  ('Restaurant-Inform',
#   'Name',
#   'the gardenia',
#   'Yes, please book a table for 1 people at 19:15 on monday.'),
#  ('Hotel-Inform', 'Name', 'el shaddai', 'Yes, can you book the room for me?'),
#  ('Train-Inform',
#   'Dest',
#   'peterborough',
#   'I need to go from Cambridge to Peterbourgh Saturday. '),
#  ('Hotel-Inform',
#   'Name',
#   'arbury lodge guesthouse',
#   'That sounds like a great place to stay. Thank you for your help!'),
#  ('Restaurant-Inform',
#   'Food',
#   'australasian',
#   'i need to eat australian food in a place that is expensive'),
#  ('Restaurant-Inform',
#   'Price',
#   'dont care',
#   'i need to eat australian food in a place that is expensive'),
#  ('Attraction-Inform',
#   'Name',
#   'milton country park',
#   'Sure.  What is their postcode and phone number?'),
#  ('Hotel-Inform',
#   'Name',
#   'university arms hotel',
#   'No, but I do need the address and postcode.'),
#  ('Attraction-Inform',
#   'Name',
#   'all saints church',
#   'Can I get their phone number and address please?'),
#  ('Attraction-Inform',
#   'Type',
#   'swimmingpool',
#   'Parks for kids or a water slide'),
#  ('Restaurant-Inform',
#   'Name',
#   'the oak bistro',
#   'That sounds great. Can you book that for Tuesday at 12:00?'),
#  ('Attraction-Inform',
#   'Type',
#   'mutiple sports',
#   'Do you have any multiple sports?'),
#  ('Restaurant-Inform',
#   'Price',
#   'moderate',
#   'I am looking for a restaurant that serves Modern European food at a reasonable price. '),
#  ('Restaurant-Inform',
#   'Name',
#   'riverside brasserie',
#   'Is that in the centre of town? Is it moderately priced? '),
#  ('Restaurant-Inform',
#   'Name',
#   'dojo noodle bar',
#   'Yes please, for 8 people at 18:30 on thursday.'),
#  ('Attraction-Inform',
#   'Type',
#   'architecture',
#   "Why don't you try an architectural attraction, instead."),
#  ('Hotel-Inform',
#   'Name',
#   'a and b guest house',
#   'That sounds just fine, so long as it is rated 3 stars.'),
#  ('Train-Inform',
#   'Arrive',
#   '10:30',
#   "I'm looking for a train that leaves on Saturday and arrives by 10.30"),
#  ('Attraction-Inform',
#   'Name',
#   'clare college',
#   'That sounds great! Could you give me the entrance fee, postcode, and address?'),
#  ('Taxi-Inform',
#   'Arrive',
#   '17:15',
#   'Could you also book me a taxi that arrives at the restaurant by the time of my reservation?'),
#  ('Taxi-Inform',
#   'Depart',
#   'ashley hotel',
#   'From the hotel.  I would like to get a contact number for the taxi also, just in case something changes.'),
#  ('Restaurant-Inform',
#   'Name',
#   'yippee noodle bar',
#   "Sure, I'll try it. Can I get their phone number and post code?"),
#  ('Taxi-Inform',
#   'Depart',
#   'arbury lodge guesthouse',
#   'I will need to be picked up at the hotel by 4:45 to arrive at the college on tuesday.'),
#  ('Restaurant-Inform',
#   'Name',
#   'curry prince',
#   'Yes, please book it at 14:00 on Saturday for 1.'),
#  ('Restaurant-Inform',
#   'Name',
#   'midsummer house restaurant',
#   'Also looking for a restaurant by the name of Midsummer House. I need a reservation for 7 people at 10:15 on Monday.'),
#  ('Restaurant-Inform',
#   'Name',
#   'cote',
#   'Yes, please. I need a table for 8 on Friday at 17:30, please.'),
#  ('Restaurant-Inform',
#   'Name',
#   'anatolia',
#   'Yes, I need a reservation for 1 people at 14:00 on monday.'),
#  ('Attraction-Inform',
#   'Name',
#   'broughton house gallery',
#   'Okay can you provide me with their address, phone number and postcode please?'),
#  ('Restaurant-Inform',
#   'Name',
#   'chiquito restaurant bar',
#   'Can I have the phone number and post code for that please?'),
#  ('Restaurant-Inform',
#   'Price',
#   'moderate',
#   'Thanks. Now can you look up a welsh food restaurant that is expensive and in the centre?'),
#  ('Hotel-Inform',
#   'Name',
#   'allenbell',
#   'That sounds alright. Do they have free parking?'),
#  ('Hotel-Inform',
#   'Day',
#   'sunday',
#   'Yes please. I would like it for 8 people for 5 nights starting from Monday.'),
#  ('Restaurant-Inform',
#   'Price',
#   'dont care',
#   'No I really wanted an expensive place in Centre that serves New Zealand cuisine. '),
#  ('Restaurant-Inform',
#   'Price',
#   'expensive',
#   'How about on Wednesday, the same time for 2?'),
#  ('Hotel-Inform',
#   'Name',
#   'worth house',
#   "Let's make a booking for 6 people, 5 nights starting wednesday"),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'Sounds great,and I will take it!'),
#  ('Restaurant-Inform',
#   'Name',
#   'the oak bistro',
#   'That sounds like it will do. Can you reserve a table for the same group of people at 15:15 on the same day, please?'),
#  ('Train-Inform',
#   'Leave',
#   '17:30',
#   'I would like to leave after 17;15 on sunday.'),
#  ('Hotel-Inform',
#   'Name',
#   'allenbell',
#   'No I just need the phone number. Thanks '),
#  ('Hotel-Inform',
#   'Name',
#   'ashley hotel',
#   'Yes I would, for 5 people please for 2 nights starting on Thursday. '),
#  ('Hotel-Inform',
#   'Stars',
#   'dont care',
#   "That isn't really important for me. Please recommend one and book it for six people. "),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'Yes, please book the room and can I have the reference number '),
#  ('Hotel-Inform',
#   'Price',
#   'expensive',
#   'A FOUR STAR RATING,WITH A PRICE RANGE IN THE NEIGHBORHHOOD OF 1000 POUNDS. PLEASE I WOULD LIKE TO BE IN THE LONDON,ENGLAND AREA IF I MAY TO BE NEAR THE CLUBS.'),
#  ('Restaurant-Inform',
#   'Name',
#   'bangkok city',
#   'Yes, please. Make me a reservation for 4 people at 13:30 on thursday, please.'),
#  ('Train-Inform',
#   'Day',
#   'saturday',
#   'Im traveling to Cambridge from london liverpool street arriving by 11:45 the day of my hotel booking.'),
#  ('Restaurant-Inform',
#   'Name',
#   'sala thong',
#   'Can I book a table for 6 people at 15:45 on Tuesday?'),
#  ('Restaurant-Inform',
#   'Area',
#   'centre',
#   'Can you help me find a place to eat in the expensive price range in the south part of town?'),
#  ('Hotel-Inform',
#   'Name',
#   'the lensfield hotel',
#   'Yes please, two people for two nights on sunday.'),
#  ('Hotel-Inform',
#   'Name',
#   'the cambridge belfry',
#   'No, just need to make sure it includes free parking.'),
#  ('Hotel-Inform',
#   'Name',
#   'avalon',
#   'Do you know what area that is in and whether they have internet? '),
#  ('Train-Inform', 'Leave', '09:00', 'I need to travel after 9am'),
#  ('Train-Inform', 'People', '1', "Yes it's just going to be me."),
#  ('Restaurant-Inform',
#   'Food',
#   'north american',
#   "Yes, I'm looking for a restaurant that serves American food and is in the center of town."),
#  ('Hotel-Inform', 'Name', 'allenbell', 'Sure, Can I have a reference Number?'),
#  ('Hotel-Inform',
#   'Name',
#   'allenbell',
#   'please and I need postcode and confirm number '),
#  ('Taxi-Inform',
#   'Depart',
#   'la raza',
#   'I will be departing from the restaurant. '),
#  ('Attraction-Inform',
#   'Name',
#   'broughton house gallery',
#   'Could you tell me the attraction type and entrance fee?'),
#  ('Train-Inform',
#   'Dest',
#   'broxbourne',
#   'I would like to go from cambridge to boxbourne on friday.'),
#  ('Hotel-Inform', 'Day', 'saturday', 'How about tuesday?'),
#  ('Hotel-Inform',
#   'Name',
#   'autumn house',
#   'Yes I would. I need it for 3 nights & 3 people starting on Monday.'),
#  ('Restaurant-Inform',
#   'Price',
#   'dont care',
#   'no price range but I would need the postcode and phone number'),
#  ('Hotel-Inform',
#   'Name',
#   'limehouse',
#   "Awesome, thanks a lot. That's all I needed help with today. "),
#  ('Restaurant-Inform',
#   'Name',
#   'curry garden',
#   'That sounds great can I get their address and phone number'),
#  ('Attraction-Inform',
#   'Name',
#   'cafe jello gallery',
#   'Oh that does sound fun. What is the entrance fee? Also can I have the address and postcode?'),
#  ('Hotel-Inform',
#   'Name',
#   'huntingdon marriott hotel',
#   'I am also looking for a particular hotel named huntington marriott hotel. '),
#  ('Restaurant-Inform',
#   'Name',
#   'don pasquale pizzeria',
#   'That sounds great. Please book it for 8 on Saturday at 14:15 and get a reference number.'),
#  ('Train-Inform',
#   'Dest',
#   'kings lynn',
#   'I will be going from Canbrige arriving in Kingls Lynn. '),
#  ('Restaurant-Inform', 'Name', 'charlie ', 'Yes. Monday, 8 people, 10:30. '),
#  ('Hotel-Inform',
#   'Name',
#   'autumn house',
#   'Yes. That sounds great. Please try to book it.'),
#  ('Taxi-Inform',
#   'Depart',
#   'the cambridge belfry',
#   'I would like to be picked up at the cambridge belfy and go to the cambridge shop.'),
#  ('Taxi-Inform',
#   'Dest',
#   'the cambridge chop house',
#   'I would like to be picked up at the cambridge belfy and go to the cambridge shop.'),
#  ('Restaurant-Inform',
#   'Price',
#   'expensive',
#   'Is there another restaurant in the area in that price range that is available at that time?'),
#  ('Train-Inform',
#   'Day',
#   'monday',
#   'I am looking for a train to pick me up at Birmingham New Street and arrive in Cambridge before 12:00 on the day of my reservation.'),
#  ('Restaurant-Inform',
#   'Name',
#   'yippee noodle bar',
#   "I'm not sure right now. May I please have the postcode?"),
#  ('Restaurant-Inform',
#   'Name',
#   'cocum',
#   'Ok, that would be fine. Can you please send me the reference number?'),
#  ('Restaurant-Inform',
#   'Food',
#   'seafood',
#   'I need a place to eat that serves sea food. '),
#  ('Restaurant-Inform',
#   'Food',
#   'dont care',
#   "I'd love to try some European food."),
#  ('Restaurant-Inform',
#   'Name',
#   'eraina',
#   'Yes, I need a table for 7 please at 18:00. '),
#  ('Hotel-Inform',
#   'Name',
#   'dont care',
#   "I'm also wanting to stay at the Alpha-Milton Guest House.  Can you help with that?"),
#  ('Taxi-Inform',
#   'Arrive',
#   '11:15',
#   "I need to arrive at the restaurant in time for our reservation. Wouldn't want to miss my booked time."),
#  ('Hotel-Inform',
#   'Stars',
#   '4',
#   'If there is no hotel availability, I will accept a guesthouse.  Is one available?'),
#  ('Hotel-Inform',
#   'Name',
#   'aylesbray lodge guest house',
#   "That will work fine. Could you make a reservation for 3? I'd like it for 5 nights starting Saturday. "),
#  ('Restaurant-Inform',
#   'Area',
#   'Center',
#   'Could you recommend a restaurant that serves indian food is expensive, and in the centre?'),
#  ('Restaurant-Inform',
#   'Name',
#   'curry queen',
#   'Sounds great! Can you set up a reservation?'),
#  ('Attraction-Inform',
#   'Name',
#   'broughton house gallery',
#   'Yes, could you please give me their phone number?'),
#  ('Hotel-Inform',
#   'Post',
#   'ce12de ',
#   '56 saint barnabas road postcode ce12de\nalexander bed and breakfast '),
#  ('Restaurant-Inform',
#   'Food',
#   'dont care',
#   'Ok, well what do we have in the north area?'),
#  ('Restaurant-Inform',
#   'Name',
#   'royal spice',
#   'No, I can do that.  Could you give me the phone number?  Also, the address with postcode?'),
#  ('Attraction-Inform',
#   'Name',
#   'cherry hinton hall and grounds',
#   'Okay that sounds good.  What is the area and postcode?'),
#  ('Hotel-Inform',
#   'Name',
#   'avalon',
#   "I'd like to book the room for 4 people, for 4 nights, starting Saturday.  Please provide me with the reference number."),
#  ('Train-Inform',
#   'People',
#   '4',
#   'Can you book the train for my entire group of people and give me the reference number please? '),
#  ('Taxi-Inform',
#   'Arrive',
#   '14:30',
#   'I would like to arrive at the restaurant in time for my booking.'),
#  ('Hotel-Inform',
#   'Name',
#   'university arms hotel',
#   'book it for 7 people and 5 nights starting from wednesday.'),
#  ('Attraction-Inform',
#   'Name',
#   'broughton house gallery',
#   'Yes, please give me the postcode, entrance fee and address.'),
#  ('Attraction-Inform',
#   'Type',
#   'dont care',
#   'Yes sure as long as the attraction is in the city center. Could you also provide me with the phone number and postcode of the attraction?'),
#  ('Hotel-Inform',
#   'Name',
#   'allenbell',
#   'that is fine. book for 8 people and 5 nights from friday'),
#  ('Train-Inform',
#   'Dest',
#   'cambridge',
#   'Any time that lets me arrive by 08:45.'),
#  ('Attraction-Inform',
#   'Name',
#   'whipple museum of the history of science',
#   'I would like the phone number and entrance fee to the Whipple Museum.'),
#  ('Attraction-Inform',
#   'Name',
#   'holy trinity church',
#   'What is their phone number?'),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'Yes, I do need to book a room.'),
#  ('Taxi-Inform',
#   'Arrive',
#   '14:45',
#   "That sounds great. Yes, actually, I'd like to book a taxi to go from the college to the restaurant please, so we can arrive in time for our reservation."),
#  ('Restaurant-Inform',
#   'Name',
#   'the nirala',
#   "Yes, please. We'd like a table for 3 at 15:30 on Tuesday."),
#  ('Hotel-Inform',
#   'Name',
#   'a and b guest house',
#   "Sure, please book it for 3 people. We'll arrive tuesday and stay for 2 nights."),
#  ('Restaurant-Inform', 'Name', 'curry king', 'Thanks, what is their address?'),
#  ('Hotel-Inform',
#   'Name',
#   'the lensfield hotel',
#   "Yes, I want to stay there for 2 nights starting wednesday. It'll be just 1 person again. Please provide a reference number."),
#  ('Hotel-Inform',
#   'Name',
#   'leverton house',
#   'Yes please, can I also have the reference number?'),
#  ('Hotel-Inform', 'Name', 'university arms hotel', 'Great. That will work. '),
#  ('Restaurant-Inform',
#   'Food',
#   'indian',
#   'In the same area as Cambridge Artworks.'),
#  ('Restaurant-Inform',
#   'Name',
#   'curry prince',
#   'Yes. I need to book it for Saturday at 17:30. Just for me.'),
#  ('Hotel-Inform',
#   'Name',
#   'a and b guest house',
#   'No, I just need to know if they have free parking.'),
#  ('Restaurant-Inform',
#   'Name',
#   'the golden curry',
#   "I would like it for just me because I don't have friends, for 11:45 on Tuesday. "),
#  ('Hotel-Inform',
#   'Name',
#   'carolina bed and breakfast',
#   'Yes, sounds perfect. I want to book it for 4 nights. There will be 8 people and we will be arriving on Thursday.'),
#  ('Attraction-Inform',
#   'Name',
#   'cambridge arts theatre',
#   'Cambridge Arts sounds good, can I get the phone number? Is there any entrance fee? And then a nice expensive dinner in the same area please.'),
#  ('Restaurant-Inform',
#   'Name',
#   'da vinci pizzeria',
#   'Yes, please book it for 13:30 on Saturday for 8 people.'),
#  ('Hotel-Inform',
#   'Area',
#   'centre',
#   'Is there anything within walking distance of the Jinling?   '),
#  ('Hotel-Inform',
#   'Day',
#   'saturday',
#   'I am looking for a hotel with free wifi available for 3 people for 3 nights starting sunday'),
#  ('Attraction-Inform',
#   'Name',
#   'cherry hinton hall and grounds',
#   'Yes. What is the postcode and phone number? Also, I am needing a 4 star hotel in the same area. Can you check if one is available for me?'),
#  ('Attraction-Inform',
#   'Name',
#   'churchill college',
#   'Thank you! Just give me the postcode and I should be good to go.'),
#  ('Taxi-Inform',
#   'Dest',
#   'maharajah tandoori restaurant',
#   "I'm headed to Tandoori Palace from the College."),
#  ('Train-Inform',
#   'Dest',
#   'cambridge',
#   'wednesday and I want to get there by 08:00 leaving broxbourne, how much is that?'),
#  ('Attraction-Inform',
#   'Area',
#   '  centre',
#   "There are only boat attractions in the east, north and centre so If i was you I wouldn't stay in the west or south."),
#  ('Restaurant-Inform', 'Name', 'cotto', 'Yes can I please get more info. '),
#  ('Hotel-Inform',
#   'Stars',
#   'four star',
#   'Maybe, if possible, I would like a guesthouse that is also 4 star in the east in addition to being moderate.'),
#  ('Attraction-Inform',
#   'Name',
#   'nusha',
#   'Okay, please provide me with the postcode, and also I want a taxi to take me there. It should leave the hotel by 10:30. Give me car type and contact number'),
#  ('Attraction-Inform',
#   'Name',
#   'all saints church',
#   'Alright, please tell me the phone number and address there, as well as the entrance fee'),
#  ('Restaurant-Inform',
#   'Food',
#   '  Indian ',
#   'There are Australian restaurants in the area however there are 22 Indian restaurants. Is there an area of town you prefer?'),
#  ('Attraction-Inform',
#   'Name',
#   'clare college',
#   'Sure, can you give me the address for that?  You said it is in the west, right?'),
#  ('Restaurant-Inform',
#   'Name',
#   'pizza express',
#   'No thank you but I do need the phone number. '),
#  ('Attraction-Inform',
#   'Name',
#   "christ's college",
#   "What's the entrance fee, address, and phone number?"),
#  ('Hotel-Inform',
#   'Name',
#   'express by holiday inn cambridge',
#   'Does it have free parking?'),
#  ('Attraction-Inform',
#   'Type',
#   'mutliple sports',
#   'How about multiple sports?'),
#  ('Attraction-Inform', 'Type', 'theatre', 'How about a theater in the south?'),
#  ('Restaurant-Inform',
#   'Name',
#   'chiquito restaurant bar',
#   'Can I have the area and address please not sure if I want to book it yet?'),
#  ('Restaurant-Inform',
#   'Name',
#   'restaurant alimentum',
#   'Yes I would like a reservation for 6 people at 10:45 on saturday please. '),
#  ('Hotel-Inform',
#   'Name',
#   'aylesbray lodge guest house',
#   'Can you book that for 1 person for 3 nights starting saturday?'),
#  ('Train-Inform',
#   'Dest',
#   'cambridge',
#   'Actually I need to go to London Liverpool Street from Cabridge.'),
#  ('Hotel-Inform',
#   'Name',
#   'el shaddai',
#   'Definitely! There will be 6 of us, arriving Saturday, and staying for 5 nights.'),
#  ('Hotel-Inform',
#   'Name',
#   'gonville hotel',
#   "Yes please. It's for 2 people and 2 nights starting on Thursday. "),
#  ('Hotel-Inform',
#   'Day',
#   'wednesday',
#   "It's just for me, and I'll be staying for three nights starting from Tuesday."),
#  ('Attraction-Inform',
#   'Name',
#   'all saints church',
#   'Yes, could you provide me with their address.'),
#  ('Attraction-Inform',
#   'Name',
#   'churchill college',
#   'Sure can I get the phone number to this college?'),
#  ('Restaurant-Inform', 'Food', 'moroccan', 'Is there any Morrocan food?'),
#  ('Restaurant-Inform',
#   'Name',
#   'golden wok',
#   "Yes, I'd like to book for Thursday at 17:15 with 3 people. Send me the reference number too. "),
#  ('Taxi-Inform', 'Depart', 'ashley hotel', 'I need picked up at the hotel.'),
#  ('Restaurant-Inform',
#   'Name',
#   'charlie chan',
#   'That sounds great. Can I get a table for 8 people at 16:45 on Saturday?'),
#  ('Taxi-Inform',
#   'Depart',
#   'acorn guest house',
#   'From the guesthouse to the restaurant'),
#  ('Hotel-Inform',
#   'Name',
#   'hamilton lodge',
#   'Yes, please. 4 people for 4 nights starting on Monday.'),
#  ('Restaurant-Inform',
#   'Name',
#   'kohinoor',
#   "Thank you. I'd like to book a table for 6 people for Wednesday at 18:15. Also can you provide a reference number to confirm."),
#  ('Train-Inform',
#   'Dest',
#   'peterborough',
#   'From cambridge to petersborough. I am looking for thursday after 12:15'),
#  ('Hotel-Inform',
#   'Name',
#   'express by holiday inn cambridge',
#   'Sounds good. I need the postcode please.'),
#  ('Restaurant-Inform',
#   'Name',
#   'tandoori palace',
#   'Can you check to see if they have booking available for 8 people at 19:45 on Sunday?'),
#  ('Hotel-Inform',
#   'Name',
#   'hamilton lodge',
#   'Okay sounds great, can you book a room for me?'),
#  ('Restaurant-Inform',
#   'Name',
#   'the cow pizza kitchen and bar',
#   'Yes please.  But you can go ahead at book it for 3 people at 17:30 on Thursday.'),
#  ('Restaurant-Inform',
#   'Name',
#   'bedouin',
#   'Yes. Please book for 7 people on Thursday at 12:30.'),
#  ('Restaurant-Inform',
#   'Name',
#   'zizzi cambridge',
#   'That sounds perfect. Can you book me a table for 3 on Thursday at 18:45?'),
#  ('Hotel-Inform',
#   'Name',
#   'hobsons house',
#   'That sounds great. I would like to book it for 4 people and 2 nights starting from Tuesday.'),
#  ('Hotel-Inform',
#   'Name',
#   'el shaddai',
#   'No, but I do need a reservation for Wednesday, 2 nights, for 3 people.'),
#  ('Attraction-Inform',
#   'Area',
#   'west',
#   'Yes, I need an attraction in the weat'),
#  ('Hotel-Inform',
#   'Area',
#   'west',
#   'Are any of those in the moderate price range?'),
#  ('Restaurant-Inform',
#   'Name',
#   'yippee noodle bar',
#   'That would be great. I need to for 2 people at 13:00 on Tuesday. Can you provide the reference number for the reservation?'),
#  ('Hotel-Inform',
#   'Name',
#   'alexander bed and breakfast',
#   'Sounds great. Can you please book that for me for Tuesday for 2 people, 2 nights please?'),
#  ('Attraction-Inform',
#   'Name',
#   'broughton house gallery',
#   'whats its postcode and address? i would also like to get a train that leaves friday from kings lynn'),
#  ('Restaurant-Inform',
#   'Price',
#   'cheap',
#   'Yes, something in the affordable price range. Also, do any of them serve singaporean food?'),
#  ('Hotel-Inform',
#   'Name',
#   'finches bed and breakfast',
#   'Do they have free parking?'),
#  ('Attraction-Inform',
#   'Type',
#   'college',
#   "I'd like to book a taxi leaving the hotel by 21:00.  I'd also like the contact number and car type."),
#  ('Restaurant-Inform',
#   'Price',
#   'moderate',
#   "What's a good mid price restaurant?"),
#  ('Train-Inform',
#   'Dest',
#   'cambridge',
#   "Yes, you're right. I need to leave on Monday, and I need to arrive by 18:15."),
#  ('Attraction-Inform',
#   'Name',
#   'vue cinema',
#   'Sounds good!  Could I have the address and entrance fee, please?'),
#  ('Hotel-Inform', 'Name', 'allenbell', 'Please reserve a room for 1.'),
#  ('Hotel-Inform',
#   'Price',
#   'moderate',
#   'I am looking for price range that is not cheap or expensive.'),
#  ('Hotel-Inform',
#   'Name',
#   'the cambridge belfry',
#   'Yes, please. For 3 nights, and starting on Friday.'),
#  ('Hotel-Inform',
#   'Name',
#   'ashley hotel',
#   'That sounds like it might be great - how many stars does the Ashley have?'),
#  ('Taxi-Inform',
#   'Dest',
#   'graffiti',
#   'I just need to get to the restaurant by the time the reservation starts.'),
#  ('Taxi-Inform',
#   'Arrive',
#   '14:45',
#   'I just need to get to the restaurant by the time the reservation starts.'),
#  ('Taxi-Inform',
#   'Depart',
#   'ashley hotel',
#   'Please have the taxi pick me up at the hotel. Can I get the taxi contact number and car type?'),
#  ('Restaurant-Inform', 'Food', 'asian oriental', 'I would prefer Asian food.'),
#  ('Restaurant-Inform',
#   'Name',
#   'sala thong',
#   'That sounds good. Can you book me a table on Thursday at 16:30?'),
#  ('Restaurant-Inform',
#   'Area',
#   'north',
#   'Nearest the hotel will be fine, I also need a cab after the restaurant'),
#  ('Taxi-Inform',
#   'Dest',
#   'acorn guest house',
#   'I would like to go back to the hotel after eating'),
#  ('Taxi-Inform',
#   'Arrive',
#   '15:45',
#   'I also need a taxi to commute between both places, and could you make sure it arrives at the restaurant by the booked time?'),
#  ('Restaurant-Inform',
#   'Name',
#   'grafton hotel restaurant',
#   'Please book reservation for 2 people at 16:00 on Friday. Send me the reference number.'),
#  ('Restaurant-Inform',
#   'Name',
#   'pizza hut fen ditton',
#   'book a table for 7 people at 15:45 on monday.'),
#  ('Restaurant-Inform',
#   'Food',
#   'french',
#   'I would like belgian food in the moderate price range. '),
#  ('Attraction-Inform',
#   'Name',
#   'castle galleries',
#   'Can I get the post code for that one?'),
#  ('Hotel-Inform',
#   'Name',
#   'express by holiday inn cambridge',
#   'Okay I want to book the 2 star hotel for 4 people for 4 nights from wednesday'),
#  ('Hotel-Inform',
#   'Name',
#   'allenbell',
#   'No thank you. Can you please give me the address?'),
#  ('Hotel-Inform',
#   'Day',
#   'saturday',
#   'Yes please. I need it for saurday, sunday, monday and tuesday please.'),
#  ('Hotel-Inform',
#   'Area',
#   'dont care',
#   "It can be anywhere in town, but I'd like the hotel to be in the cheap price range if possible."),
#  ('Attraction-Inform',
#   'Name',
#   "christ's college",
#   'Yes. The entrance fee and the phone number please. '),
#  ('Restaurant-Inform',
#   'Name',
#   'jinling noodle bar',
#   'Can I have their phone number and address? Also, are there any trains that go from Peterborough to Cambridge?'),
#  ('Hotel-Inform',
#   'Name',
#   'university arms hotel',
#   'Is it in the same price range?'),
#  ('Taxi-Inform',
#   'Depart',
#   'express by holiday inn cambridge',
#   'I would like to leave the hotel by 02:45 to go to the museum.'),
#  ('Taxi-Inform',
#   'Dest',
#   'whipple museum of the history of science',
#   'I would like to leave the hotel by 02:45 to go to the museum.'),
#  ('Hotel-Inform',
#   'Name',
#   'el shaddai',
#   'That sounds good but I need free wifi. Does it have free wifi?'),
#  ('Hotel-Inform',
#   'Name',
#   'ashley hotel',
#   'Is there room for 4 people on Monday?'),
#  ('Attraction-Inform',
#   'Name',
#   "christ's college",
#   'That sounds good. May I have the postcode, phone number and address.'),
#  ('Restaurant-Inform',
#   'Name',
#   'caffe uno',
#   'Please book a table for 2 on Monday at 18:15.'),
#  ('Hotel-Inform',
#   'Name',
#   'ashley hotel',
#   'Thank you, can you book me for that?'),
#  ('Restaurant-Inform',
#   'Name',
#   'stazione restaurant and coffee bar',
#   'Yes, that would be great. We will be dining on Saturday at 11:00. It will be 6 people. '),
#  ('Attraction-Inform',
#   'Name',
#   'cherry hinton water play',
#   "Yes, that sounds like someplace for me to visit.  Is it free?  Also, I'll need the postcode and phone number."),
#  ('Train-Inform',
#   'Day',
#   'sunday',
#   'I am looking for a train going to Cambridge on Saturday.'),
#  ('Restaurant-Inform',
#   'Name',
#   'the oak bistro',
#   'Yes, that would be great. Please book that for me. '),
#  ('Train-Inform',
#   'Depart',
#   'stansted airport',
#   'I need to depart from Stansted'),
#  ('Hotel-Inform',
#   'Stay',
#   '5',
#   'Yes. I need to make a reservation there for 8 people, arriving Friday night and departing Wednesday morning.'),
#  ('Restaurant-Inform',
#   'Name',
#   'riverside brasserie',
#   'What is the postcode of that resturant?'),
#  ('Taxi-Inform',
#   'Depart',
#   'loch fyne',
#   'The cab has to pick me up from the restaurant to the nightclub.'),
#  ('Taxi-Inform',
#   'Dest',
#   'the place',
#   'The cab has to pick me up from the restaurant to the nightclub.'),
#  ('Taxi-Inform',
#   'Arrive',
#   '11:45',
#   "Actually, I'm confused. I apologize. I'll need a taxi that will take me from the nightclub to the restaurant. I'd like to arrive by the booked time for the restaurant. "),
#  ('Train-Inform', 'People', '1', 'Just myself will be travelling.'),
#  ('Hotel-Inform', 'Name', ' Hamilton Lodge', 'Yes, please book that for me.'),
#  ('Taxi-Inform',
#   'Depart',
#   'hamilton lodge',
#   "I'll be departing from the hotel. Please give me the contact info and car type."),
#  ('Hotel-Inform',
#   'Name',
#   'alp',
#   'Yes and Can you book it for me and get a reference number ?'),
#  ('Hotel-Inform', 'Name', 'ashley hotel', 'Does the hotel have free parking?'),
#  ('Attraction-Inform',
#   'Name',
#   'the man on the moon',
#   'Could I get the phone number for the concert hall please?'),
#  ('Restaurant-Inform',
#   'Day',
#   'sunday',
#   'I want to book a table for 5 people at 13:00 on saturday.'),
#  ('Restaurant-Inform',
#   'Price',
#   'moderate',
#   'I am looking for a restaurant in the center with a moderite price range.'),
#  ('Hotel-Inform',
#   'Name',
#   'alexander bed and breakfast',
#   'Yes, please book me for four people on saturday for one night.'),
#  ('Train-Inform',
#   'Day',
#   'sunday',
#   "I'm head to Leicester from Cambridge on Saturday."),
#  ('Restaurant-Inform',
#   'Name',
#   'the cambridge chop house',
#   'That sounds lovely. There will be 2 of us at 16:45 on Tuesday please.'),
#  ('Attraction-Inform',
#   'Name',
#   'cineworld cinema',
#   'Thank you, I just need their postal code for now and I can take it from there.'),
#  ('Taxi-Inform',
#   'Arrive',
#   '16:15',
#   'Actually, I also need a taxi to arrive at the restaurant by the reservation time.'),
#  ('Restaurant-Inform',
#   'Area',
#   'south',
#   'Could you help me find a restaurant in that area?'),
#  ('Attraction-Inform',
#   'Addr',
#   '  anglia ruskin enterprise',
#   "cambridge arts theatre is at 6 saint edward's passage, mumford theatre is at anglia ruskin enterprise, east road; and the cambridge corn exchange is at wheeler street."),
#  ('Hotel-Inform',
#   'Name',
#   'bridge guest house',
#   'Yes, make the reservation please.'),
#  ('Hotel-Inform',
#   'Name',
#   "rosa's bed and breakfast",
#   'Can i just get the address please?'),
#  ('Restaurant-Inform',
#   'Name',
#   'chiquito restaurant bar',
#   "Yes. I'd like a table for 1 person at 19:15 on Sunday. "),
#  ('Restaurant-Inform',
#   'Name',
#   'zizzi cambridge',
#   'I will go with them, can you book 3 people for 12:30 on saturday?'),
#  ('Restaurant-Inform',
#   'Name',
#   'the cambridge chop house',
#   'i would like the reservation to be for sunday for 7 people at 20:15. '),
#  ('Attraction-Inform',
#   'Name',
#   'castle galleries',
#   'May I have the phone number please?'),
#  ('Hotel-Inform',
#   'Name',
#   'the cambridge belfry',
#   'That will work.I need the address please. '),
#  ('Restaurant-Inform',
#   'Food',
#   'italian',
#   'Sure, can you find me another restaurant that serves Indian food? '),
#  ('Restaurant-Inform',
#   'Name',
#   'curry prince',
#   'Yes. May I have the post code for that place?'),
#  ('Attraction-Inform',
#   'Name',
#   'club salsa',
#   'I need the entrance fee and post code. '),
#  ('Hotel-Inform',
#   'Day',
#   'sunday',
#   "Perfect! Let's book it for two nights starting Saturday. There are five people in my party. I will also need the reference number."),
#  ('Train-Inform',
#   'Leave',
#   '05:15',
#   'How long is the trip?  I might like to leave somewhat later.'),
#  ('Hotel-Inform',
#   'Name',
#   'arbury lodge guesthouse',
#   'Do you have any restaurants near there with Chinese food?'),
#  ('Restaurant-Inform',
#   'Name',
#   'the golden curry',
#   'That sounds perfect. Can you book a table for me for tuesday?'),
#  ('Hotel-Inform',
#   'Price',
#   'cheap',
#   'Just please book for that room for 2 nights.'),
#  ('Hotel-Inform',
#   'Area',
#   'east',
#   'Could you check another area of town perhaps that can accommodate 6 guests for 3 nights starting Sunday with a moderate price and free parking?'),
#  ('Taxi-Inform',
#   'Depart',
#   'ely train station',
#   'I need to leave from ely and get to sidney sussex college by 14:15.'),
#  ('Restaurant-Inform',
#   'Name',
#   'oak bistro',
#   'could I have the  area and phone number'),
#  ('Hotel-Inform',
#   'Type',
#   'guesthouse',
#   'Are the any guest house type places to stay in the north part of town available?'),
#  ('Restaurant-Inform',
#   'Price',
#   'dont care',
#   "No preferences for the price range, but I'd like it to be in the same area as the hotel."),
#  ('Restaurant-Inform',
#   'Name',
#   'pizza hut fen ditton',
#   'i want to book a table for 4 people at 21:00 on the same day as the train.'),
#  ('Restaurant-Inform',
#   'Name',
#   'bedouin',
#   "I don't need a table right now, but I do need the postcode and phone number for that restaurant."),
#  ('Hotel-Inform',
#   'Name',
#   'leverton house',
#   'That sounds good. I would like to book that for 4 people and 4 nights starting from Saturday. '),
#  ('Hotel-Inform',
#   'Price',
#   'dont care',
#   'I do not have a particular price range in mind. '),
#  ('Hotel-Inform',
#   'Name',
#   'alexander bed and breakfast',
#   'Great, can I have it for 4 people for 2 nights on wednesday and also I need a reference number? '),
#  ('Restaurant-Inform',
#   'Name',
#   'bedouin',
#   'That would be perfect if it is in expensive range. I need to book it for sunday.'),
#  ('Restaurant-Inform',
#   'Name',
#   'pizza hut fen ditton',
#   'Yes. There will be 6 of us dining.'),
#  ('Hotel-Inform',
#   'Name',
#   'alexander bed and breakfast',
#   'Can I have the number to the hotel?'),
#  ('Taxi-Inform',
#   'Car',
#   'black volkswagen ',
#   'Booking completed!\nBooked car type\t:\tblack volkswagen\nContact number\t:\t07248386378'),
#  ('Attraction-Inform',
#   'Name',
#   'parkside pools',
#   'No but I would like the address and entrance fee.'),
#  ('Train-Inform',
#   'Day',
#   'monday',
#   'I will be leaving stevenage on Wednesday. '),
#  ('Train-Inform', 'Arrive', '23:00', '11 pm and I want it for three people'),
#  ('Restaurant-Inform',
#   'Name',
#   'yippee noodle bar',
#   'Yes, 7 people at 13:30 on friday.'),
#  ('Attraction-Inform',
#   'Name',
#   "christ's college",
#   'Can you provide me with the entrance fee and postcode?'),
#  ('Hotel-Inform',
#   'Price',
#   'dont care',
#   'No but I need it to have free parking.'),
#  ('Restaurant-Inform', 'Name', 'gourmet burger kitchen', 'Yes, thanks! '),
#  ('Hotel-Inform',
#   'Price',
#   'any',
#   'Just the four star and hotel, tell me what my price options are with that one. '),
#  ('Hotel-Inform', 'Area', 'centre', 'Can you suggest one in that area?'),
#  ('Hotel-Inform',
#   'Price',
#   'dont care',
#   'Thanks I only needed the price ranges for those hotels. Have a good day. '),
#  ('Hotel-Inform',
#   'Name',
#   'the lensfield hotel',
#   'Could you give me more information the the Lensfield?'),
#  ('Hotel-Inform',
#   'Name',
#   'university arms hotel',
#   'Could I get the postcode and phone number?'),
#  ('Hotel-Inform',
#   'Stay',
#   '2',
#   'Sure! I will be staying Wednesday and Thursday. '),
#  ('Hotel-Inform',
#   'Name',
#   'aylesbray lodge guest house',
#   'Please book it for 3 people for 2 nights starting Sunday. '),
#  ('Attraction-Inform',
#   'Name',
#   'primavera',
#   'Can you give me the address to museum and the schedule a taxi to take me there.'),
#  ('Hotel-Inform',
#   'Name',
#   'alexander bed and breakfast',
#   'Yes, please book me for one person. Do they have internet and what is their phone number?'),
#  ('Attraction-Inform',
#   'Name',
#   "kettle's yard",
#   'I will need to know the entrance fee as well.  Once I get that I also need help finding a train leaving Cambridge to kings lynn after 16:45.'),
#  ('Restaurant-Inform',
#   'Price',
#   'expensive',
#   'Hello I am looking for a high-class super fancy pricey restaurant that serves south Indian food. Any suggestions would be great.'),
#  ('Restaurant-Inform',
#   'Name',
#   'curry garden',
#   'Yes.  I would like to book a table on Wednesday for 6 people at 11:00.'),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'Sounds good, can I please have their postcode and the price range?'),
#  ('Attraction-Inform',
#   'Type',
#   'mutliple sports',
#   "All of them. What's there?"),
#  ('Attraction-Inform',
#   'Name',
#   'vue cinema',
#   'Thank you that is all for now. '),
#  ('Taxi-Inform', 'Depart', 'the fez club', 'I want to leave Fez by 17:45'),
#  ('Restaurant-Inform',
#   'Name',
#   'zizzi cambridge',
#   'Sure. Sounds good. I need to book it for the same group of people on the same day at 20:15. Can I please have the reference number as well?'),
#  ('Restaurant-Inform',
#   'Name',
#   'la raza',
#   'Yes for 3 at 14:45 wednesday, can I get the reference number too please'),
#  ('Hotel-Inform',
#   'Name',
#   'gonville hotel',
#   "That would be great, thanks.  We'll have 7 people staying 5 nights starting from Sunday."),
#  ('Hotel-Inform',
#   'Stars',
#   '3',
#   'Do you have any 4 star, moderately priced hotels in that area?'),
#  ('Hotel-Inform',
#   'Area',
#   'north',
#   'How about one with the same features but in the expensive price range?'),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'yeah book it for the same group of people please'),
#  ('Restaurant-Inform',
#   'Name',
#   'royal spice',
#   'I would love that, I need it for 1 person at 17:30 on Wednesday, please include a reference number.'),
#  ('Attraction-Inform',
#   'Area',
#   'dont care',
#   "While I am in the north part of town, I'd like some help finding something to do.  Is there a popular attraction around?"),
#  ('Restaurant-Inform',
#   'Name',
#   'bedouin',
#   'Can you give me addresss and phone number please'),
#  ('Restaurant-Inform',
#   'Name',
#   'ali baba',
#   'That sounds great.  I need to book it for 5 people at 11:45 on Friday.  Can I get the reference number please?'),
#  ('Hotel-Inform',
#   'Name',
#   "rosa's bed and breakfast",
#   'Yes for one person for 4 nights starting Friday please.'),
#  ('Attraction-Inform',
#   'Type',
#   'museum',
#   'I would like something in the Centre if possible. Perhaps a gallery?'),
#  ('Restaurant-Inform',
#   'Name',
#   'darrys cookhouse and wine shop',
#   'No thanks. That did it. I appreciate the help. Goodbye!'),
#  ('Restaurant-Inform',
#   'Name',
#   'hakka',
#   'No but can I make a booking for 8 people at 18:30 on sunday.'),
#  ('Train-Inform', 'Arrive', '09:00', "Ely. Oh and I'll need to arrive by 9."),
#  ('Train-Inform',
#   'Dest',
#   'bishop stortford',
#   'I think you should try again. Cambridge to Bishop Stafford on Thursday. '),
#  ('Hotel-Inform',
#   'Name',
#   'archway house',
#   'Sure, thanks, for 6 people, for 2 nights, starting Thursday, please!'),
#  ('Hotel-Inform',
#   'Name',
#   'university arms hotel',
#   'As long as it has wifi.Can you book it for me ?'),
#  ('Hotel-Inform',
#   'Stay',
#   '2',
#   'I would like to check in on Monday and stay till Thursday.  Just me and my wife.'),
#  ('Restaurant-Inform',
#   'Name',
#   'thanh binh',
#   'May I have their phone number please?'),
#  ('Hotel-Inform',
#   'Name',
#   'express by holiday inn cambridge ',
#   'Okay can you book it for me for 3 nights from Friday for 2 people?'),
#  ('Hotel-Inform', 'Name', 'acorn guest house', 'That sounds great! '),
#  ('Hotel-Inform',
#   'Name',
#   'the lensfield hotel',
#   'Great can you give me the phone number?'),
#  ('Hotel-Inform',
#   'Name',
#   'avalon',
#   "Sounds great. I'd like to make a reservation for Saturday."),
#  ('Hotel-Inform',
#   'Name',
#   'arbury lodge guesthouse',
#   'What area is the Arbury Lodge in?'),
#  ('Taxi-Inform',
#   'Arrive',
#   '1530',
#   'I just need to make sure I get to Yu Garden by 15:30.'),
#  ('Hotel-Inform', 'Name', 'acorn guest house', 'Yes, that would be great! '),
#  ('Attraction-Inform',
#   'Name',
#   'cafe jello gallery',
#   'That will work, can you give me the address and the entrance fee?'),
#  ('Attraction-Inform',
#   'Name',
#   'all saints church',
#   'Yes, can you please send that to me?'),
#  ('Attraction-Inform',
#   'Name',
#   'downing college',
#   'No thank you. You have been very helpful. Have a great day.'),
#  ('Restaurant-Inform', 'Name', 'curry king', 'Yes, 1 person, sunday at 21:00'),
#  ('Hotel-Inform',
#   'Name',
#   'finches bed and breakfast',
#   'Great. I need it for 7 for 5 nights.'),
#  ('Restaurant-Inform',
#   'Name',
#   'ali baba',
#   'Can you make me a reservation for Thursday for 7 people at 19:00?'),
#  ('Hotel-Inform',
#   'Name',
#   'allenbell',
#   'book it for 7 people and 5 nights starting from saturday.'),
#  ('Hotel-Inform',
#   'Name',
#   'lovell lodge',
#   'Yes please. I need the reservation to be for 5 people and 4 nights starting on Friday. '),
#  ('Taxi-Inform',
#   'Dest',
#   'hakka',
#   'To the restaurant, I would like to arrive before the reservation time of 18:45.'),
#  ('Restaurant-Inform',
#   'Name',
#   'kymmoy',
#   'Yes please can you make a reservation for 5 people at 20:00 on Sunday.'),
#  ('Hotel-Inform',
#   'Price',
#   'dont care',
#   'no. it should free packing and located in the west'),
#  ('Hotel-Inform',
#   'Name',
#   'cambridge',
#   'Yeah, please book me for 6 people, on saturday at 14:00'),
#  ('Restaurant-Inform',
#   'Name',
#   'cambridge lodge restaurant',
#   'Yeah, please book me for 6 people, on saturday at 14:00'),
#  ('Taxi-Inform',
#   'Depart',
#   'a and b guest house',
#   'Picked up at the hotel and sent to the restaurant by the booking time please.'),
#  ('Restaurant-Inform',
#   'Addr',
#   '  King Street City Centre',
#   'One is at \t30 Bridge Street City Centre, and the other is at King Street City Centre'),
#  ('Restaurant-Inform',
#   'Name',
#   'j restaurant',
#   'book for 3 people at 19:00 on sunday'),
#  ('Taxi-Inform',
#   'Depart',
#   'all saints church',
#   'The hotel and the restaurant.'),
#  ('Taxi-Inform', 'Dest', 'j restaurant', 'The hotel and the restaurant.'),
#  ('Hotel-Inform',
#   'Stay',
#   '4',
#   'Yes, go ahead and book either of those for 2 people and 3 nights beginning on Tuesday.'),
#  ('Hotel-Inform',
#   'Day',
#   'Tuesday ',
#   'Yes, go ahead and book either of those for 2 people and 3 nights beginning on Tuesday.'),
#  ('Hotel-Inform',
#   'Name',
#   'gonville hotel',
#   'Yes, go ahead and book either of those for 2 people and 3 nights beginning on Tuesday.'),
#  ('Hotel-Inform',
#   'Name',
#   'arbury lodge guesthouse',
#   'That sounds good. Can I get that for 8 people for 4 nights starting Thursday?'),
#  ('Attraction-Inform',
#   'Name',
#   'byard art',
#   'Sounds good to me! Can you give me their phone and address? Oh, and how much does it cost to get in?'),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'Could you please book it for 6 people staying 5 nights from Friday?'),
#  ('Attraction-Inform',
#   'Type',
#   'dont care',
#   'Yes, could you please give me some information on parks, pools, and the sports centre?     I just need the address and cost of admission please.'),
#  ('Hotel-Inform',
#   'Name',
#   'university arms hotel',
#   "Let's go with the one in the Centre. I need 5 nights starting Friday for 2 people."),
#  ('Attraction-Inform',
#   'Name',
#   'vue cinema',
#   'Can I have the postcode and phone number? '),
#  ('Restaurant-Inform', 'Food', 'german', 'Yes, if there is one available.'),
#  ('Attraction-Inform',
#   'Name',
#   'all saints church',
#   'That attraction works, can I have more information?'),
#  ('Taxi-Inform',
#   'Arrive',
#   '17:00',
#   "Okay, great. I'll also need a taxi to commute between the two places. I'll need to arrive at the restaurant by the booked time. "),
#  ('Attraction-Inform',
#   'Name',
#   'cherry hinton water play',
#   'If i could just get the phone number that would be great. '),
#  ('Hotel-Inform',
#   'Name',
#   'warkworth house',
#   "Yes, please! 5 of us will be staying for 3 nights, and we're arriving on Friday."),
#  ('Restaurant-Inform',
#   'Food',
#   'dont care',
#   "Well let's try another type of food that is moderately priced. What do you suggest?"),
#  ('Restaurant-Inform',
#   'Name',
#   'bloomsbury restaurant',
#   'Im also looking for some entertainment near the restaurant. '),
#  ('Attraction-Inform',
#   'Name',
#   'club salsa',
#   'Yes, I would also like to get a taxi too. I would like to know the contact number and car type also.'),
#  ('Taxi-Inform',
#   'Depart',
#   'bloomsbury restaurant',
#   'I want to book a taxi to commute between the two places.'),
#  ('Taxi-Inform',
#   'Dest',
#   'club salsa',
#   'I want to book a taxi to commute between the two places.'),
#  ('Restaurant-Inform',
#   'Name',
#   'nandos city centre',
#   'Yes please, on Wednesday at 20:30 for 5 people.'),
#  ('Attraction-Inform',
#   'Type',
#   'mutliple sports',
#   'I was thinking something related to multiple sports'),
#  ('Attraction-Inform',
#   'Name',
#   'cambridge arts theatre',
#   'That would be great. Can I have the postcode, address, and entrance fee please?'),
#  ('Attraction-Inform',
#   'Name',
#   'museum of archaelogy and anthropology',
#   'Tell me more about the anthropology museum please.'),
#  ('Attraction-Inform',
#   'Name',
#   'museum of classical archaeology',
#   'I would like a booking and the reference number.'),
#  ('Taxi-Inform',
#   'Depart',
#   'cherry hinton water play',
#   'I would only require arriving to the restaurant by the booked time.'),
#  ('Taxi-Inform',
#   'Arrive',
#   '19:30',
#   'I just need to arrive at the restaurant by the booked time.'),
#  ('Hotel-Inform', 'Name', 'allenbell', 'Does it have free wifi?'),
#  ('Attraction-Inform',
#   'Name',
#   'churchill college',
#   'Can you give me the phone number also?'),
#  ('Restaurant-Inform',
#   'Name',
#   'kohinoor',
#   'Sounds good. Can I get their phone number and address? '),
#  ('Hotel-Inform',
#   'Area',
#   'south',
#   'I want it in the west, and it should be moderately priced.'),
#  ('Hotel-Inform',
#   'Name',
#   'bridge guest house',
#   'That would be all thank you very much.'),
#  ('Taxi-Inform',
#   'Depart',
#   'university arms hotel',
#   'From the hotel to the museum, leaving by 22:00.'),
#  ('Hotel-Inform',
#   'Name',
#   'the cambridge belfry',
#   'Is that a hotel? I need a hotel and not a guesthouse. '),
#  ('Attraction-Inform',
#   'Name',
#   'milton country park',
#   'Can I get their address please? '),
#  ('Hotel-Inform',
#   'Name',
#   'hamilton lodge',
#   'I need their info. Address and phone number. '),
#  ('Taxi-Inform',
#   'Phone',
#   '07013802794 ',
#   '\nBooking completed!\nBooked car type\t:\tblue toyota\nContact number\t:\t07013802794\nCan I help you with anything else today?'),
#  ('Hotel-Inform',
#   'Type',
#   'dont care',
#   'Yes, can you help me find a place to stay, a 4 star hotel?'),
#  ('Taxi-Inform',
#   'Depart',
#   'pizza hut',
#   'I need it to go from the restaurant to the hotel.'),
#  ('Taxi-Inform',
#   'Dest',
#   'huntingdon marriott hotel',
#   'I need it to go from the restaurant to the hotel.'),
#  ('Taxi-Inform',
#   'Car',
#   'blue bmw ',
#   'Booking completed!\nBooked car type\t:\tblue bmw\nContact number\t:\t07611077714\n'),
#  ('Hotel-Inform',
#   'Name',
#   'a and b guest house',
#   'Yes for 8 for 3 nights starting sunday'),
#  ('Hotel-Inform',
#   'Name',
#   'a and b guest house',
#   'Yes.  I need it for 6 people for 5 nights starting on Friday.'),
#  ('Taxi-Inform',
#   'Dest',
#   'wandlebury country park',
#   'I want a taxi from the restaurant that I am at'),
#  ('Hotel-Inform',
#   'Area',
#   'cambridge',
#   "Oh for sure. Uh let's try something with 2 stars and moderately priced."),
#  ('Hotel-Inform', 'Name', 'ashley hotel', 'Try a 1 night stay, instead.'),
#  ('Attraction-Inform',
#   'Name',
#   "little saint mary's church",
#   'Oh, great!  Can you get me the phone number, postcode, and how much does it cost to get in?'),
#  ('Taxi-Inform',
#   'Depart',
#   'kings hedges learner pool',
#   "This conversation has gotten a little confused, hasn't it? I'd like to go to King Hedges Learner pool, please. "),
#  ('Restaurant-Inform',
#   'Name',
#   'fitzbillies restaurant',
#   "I'll be dining alone so please make a reservation for 1 at 19:30 or 18:30, perfer 19:30 on wednesday.  Reference number please?"),
#  ('Hotel-Inform', 'Day', 'wednesday', 'I will be staying 2 days.'),
#  ('Hotel-Inform', 'Name', 'acorn guest house', 'I will be staying 2 days.'),
#  ('Restaurant-Inform',
#   'Price',
#   'dont care',
#   'No I do not need to stay within a price.'),
#  ('Attraction-Inform',
#   'Name',
#   'riverboat georgina',
#   'Yes, please.  Can I have the postcode?'),
#  ('Restaurant-Inform',
#   'Name',
#   'golden wok',
#   "Great, is it considered to be expensive it's my anniversary and I want it to be high quality food"),
#  ('Train-Inform',
#   'People',
#   '8',
#   'Yes, that would be great. Please book for 6 people.'),
#  ('Hotel-Inform',
#   'Name',
#   'lovell lodge',
#   "Yes please. I'll need it booked for Saturday, for 4 nights, and 3 people. "),
#  ('Hotel-Inform',
#   'Price',
#   'dont care',
#   'free parking and very expensive money is no object located in the north'),
#  ('Hotel-Inform',
#   'Name',
#   'ashley hotel',
#   "Yes, I'll need a room for 7 people for 3 nights on the same day."),
#  ('Taxi-Inform',
#   'Depart',
#   'nandos city centre',
#   'I want to leave from nandos, city center. '),
#  ('Train-Inform',
#   'Depart',
#   'cambridge',
#   "Yes, I'd like to go to leicester after 19:45."),
#  ('Attraction-Inform',
#   'Name',
#   "people's portraits exhibition at girton college",
#   'What kind of attraction is that specifically please?'),
#  ('Hotel-Inform',
#   'Day',
#   'friday',
#   'Yes thanks.  There will be 2 of us arriving for 5 nights on Sunday.'),
#  ('Restaurant-Inform',
#   'Name',
#   'curry garden',
#   'That sounds great. Can you book a table for 2 Sunday at 15:00? '),
#  ('Taxi-Inform',
#   'Arrive',
#   '15:00',
#   'I also need a taxi to take me from the hotel to the restaurant.  I need it to arrive by the booking time.'),
#  ('Attraction-Inform',
#   'Type',
#   'mutliple sports',
#   'How about multiple sports in the south part of time?'),
#  ('Restaurant-Inform',
#   'Name',
#   'grafton hotel restaurant',
#   'Yes, please book a table for 2 at 19:00.'),
#  ('Taxi-Inform',
#   'Depart',
#   'a and b guest house',
#   'I would like to leave the hotel by 7:00. Also, can you give me the contact number and car type once you have booked it?'),
#  ('Restaurant-Inform',
#   'Name',
#   'the missing sock',
#   'Can you book me a table for five people on Monday at six fourty five?'),
#  ('Hotel-Inform',
#   'Name',
#   'warkworth house',
# ...
#   'Express by',
#   'Yes, please book for 5 people for 3 nights starting from the same day.  Can you please give me the reference number.  Thank you!'),
#  ('Restaurant-Inform',
#   'Name',
#   'la margherita',
#   'Can I get the address, phone, and postcode please? '),
#  ('Taxi-Inform', 'Dest', 'la margherita', 'I need to go to the restaurant.'),
#  ('Restaurant-Inform',
#   'Name',
#   'loch fyne',
#   'That sounds lovely - what is their cuisine type?'),
#  ('Attraction-Inform',
#   'Name',
#   'cambridge artworks',
#   'That sounds perfect. What is the address?'),
#  ('Hotel-Inform',
#   'Name',
#   "rosa's bed and breakfast",
#   "As long as it has free wifi I'll be happy!"),
#  ('Taxi-Inform',
#   'Depart',
#   "rosa's bed and breakfast",
#   'Thank you! From the hotel to the restaurant, please.'),
#  ('Taxi-Inform',
#   'Dest',
#   'nandos',
#   'Thank you! From the hotel to the restaurant, please.'),
#  ('Taxi-Inform',
#   'Phone',
#   '07559655717 ',
#   '\nBooking completed!\nBooked car type\t:\tblack volkswagen\nContact number\t:\t07559655717\nCan I help you with anything else today?'),
#  ('Restaurant-Inform',
#   'Name',
#   'curry garden',
#   'Yes please for 3 people at 17:45 on a Sunday. I also need a reference number.'),
#  ('Hotel-Inform',
#   'Name',
#   'huntingdon marriott hotel',
#   'yeah, can you let me know if it has free parking? '),
#  ('Attraction-Inform',
#   'Name',
#   "people's portraits exhibition at girton college",
#   'That sounds good, can I have the phone number please? '),
#  ('Train-Inform',
#   'Arrive',
#   '09:00',
#   'I am leaving from Norwich on Thursday. I need to arrive by 9.'),
#  ('Hotel-Inform',
#   'Stay',
#   '2',
#   'My companion and I will arrive on Monday, staying for 5 nights, could you provide me with the reference number? We will need to book a train as well.'),
#  ('Train-Inform',
#   'Depart',
#   'cambridge',
#   "Can you get me the travel time and the departure time? That's all I need to know about the train."),
#  ('Hotel-Inform',
#   'Name',
#   'avalon',
#   "I don't need to book yet, but I would like the address."),
#  ('Restaurant-Inform',
#   'Name',
#   'wagamama',
#   'Yes please book it for 4 people at 11:15 on Monday.'),
#  ('Taxi-Inform',
#   'Depart',
#   "great saint mary's church",
#   'I need to leave the church for lunch at the restaurant before the booked time.'),
#  ('Taxi-Inform',
#   'Dest',
#   'wagamama',
#   'I need to leave the church for lunch at the restaurant before the booked time.'),
#  ('Hotel-Inform',
#   'Name',
#   'avalon',
#   'Yeah, that will be fine. It will need to be on the same day for 3 nights and 3 people. '),
#  ('Restaurant-Inform', 'People', '4', '18:30 on Sunday please.'),
#  ('Hotel-Inform',
#   'Name',
#   'alexander bed and breakfast',
#   'Yes, I need a room for 4 nights beginning on sunday.'),
#  ('Hotel-Inform',
#   'Name',
#   'ashley hotel',
#   'Yes, I would like to book it for 6 people, 4 nights beginning on Saturday.'),
#  ('Attraction-Inform',
#   'Type',
#   'theatre',
#   'Hmm I actually have no clue. Could you just recommend your favorite attraction in the centre and tell me its type and postcode please?'),
#  ('Hotel-Inform',
#   'Name',
#   'huntingdon marriott hotel',
#   'Sounds good. Can you get me a room for 2 for 5 nights starting Sunday?'),
#  ('Hotel-Inform',
#   'Name',
#   'a and b guest house',
#   'Yes, please. I need rooms for 3 people for 4 nights starting on Friday.'),
#  ('Attraction-Inform',
#   'Name',
#   'castle galleries',
#   'That sounds interesting. How much do they charge for entrance?'),
#  ('Hotel-Inform',
#   'Name',
#   "rosa's bed and breakfast",
#   'Do they have internet?'),
#  ('Attraction-Inform',
#   'Name',
#   'holy trinity church',
#   'Can I have its address please?'),
#  ('Attraction-Inform',
#   'Name',
#   'museum of archaelogy and anthropology',
#   'Thanks, I will need a taxi to get inbetween those two places.'),
#  ('Attraction-Inform',
#   'Name',
#   'cherry hinton water play',
#   'No just the postcode please.'),
#  ('Restaurant-Inform',
#   'Name',
#   'tandoori palace',
#   ' book a table for 6 people at 12:00 on wednesday'),
#  ('Attraction-Inform',
#   'Name',
#   'nusha',
#   "Yes, what's their postcode? And while you're at it, maybe their phone number, too."),
#  ('Attraction-Inform',
#   'Name',
#   'museum of archaelogy and anthropology',
#   "yeah, what's their phone number?"),
#  ('Restaurant-Inform',
#   'Name',
#   'efes restaurant',
#   'Actually can you make me a reservation for 2 people at 18:15 for Thursday?'),
#  ('Restaurant-Inform', 'Name', 'nandos', 'Yes, could I get the postcode? '),
#  ('Hotel-Inform',
#   'Name',
#   "rosa's bed and breakfast",
#   'Yes, please book the reservation and provide a reference number.'),
#  ('Hotel-Inform', 'Stay', '4', 'I need to book for Friday for 5 nights.'),
#  ('Attraction-Inform',
#   'Name',
#   'cherry hinton water play',
#   'I would need the area and address, please.'),
#  ('Hotel-Inform', 'Stars', '1', 'Yes, lets go with 4 stars.'),
#  ('Hotel-Inform',
#   'Stay',
#   '2',
#   'On Monday, please. I want a place to stay when I get there.'),
#  ('Restaurant-Inform',
#   'Name',
#   'pizza express',
#   'Can you give me the phone number of the one on Regent Street?'),
#  ('Hotel-Inform',
#   'Name',
#   'home from home',
#   'That sounds like a perfect fit. Please book it for 4 nights starting this Friday, for 3 people.'),
#  ('Restaurant-Inform',
#   'Name',
#   'maharajah tandoori restaurant',
#   'Great. I would like that. Can you book us for 8 people on Thursday at 16:45?'),
#  ('Attraction-Inform',
#   'Name',
#   'magdalene college',
#   'That sounds perfect. What is their address?'),
#  ('Restaurant-Inform',
#   'Name',
#   'dojo noodle bar',
#   'Sure. Can I get the phone number? '),
#  ('Restaurant-Inform',
#   'Food',
#   'dont care',
#   "I'm not too picky on what kind of food as long as it is good.  Can you make a few suggestions please?"),
#  ('Hotel-Inform',
#   'Name',
#   'avalon',
#   'yes, i want to book it for 1 people and 2 nights starting from thursday.'),
#  ('Hotel-Inform',
#   'Day',
#   'thursday',
#   "Yes, please. I'll need the room for three nights starting on Tuesday."),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   "Yes, please. I'll need the room for three nights starting on Tuesday."),
#  ('Attraction-Inform',
#   'Name',
#   'broughton house gallery',
#   'Thanks.  I just need the entrance fee for that gallery please.'),
#  ('Attraction-Inform', 'Type', 'museum', 'Not really. What are my options?'),
#  ('Train-Inform',
#   'Day',
#   'sunday',
#   'I will need to leave Cambridge after 8:00 on Saturday.'),
#  ('Taxi-Inform',
#   'Leave',
#   '12:00',
#   'im in Cambridge central and would like to be picked at 1200hrs'),
#  ('Taxi-Inform', 'Depart', 'cityroomz', 'I need to leave the hotel by 10:00.'),
#  ('Taxi-Inform', 'Dest', 'cityroomz', 'Going from attraction to hotel.'),
#  ('Attraction-Inform',
#   'Name',
#   'kirkwood',
#   "No, thanks. I'm just looking for information at the moment. Could you tell me anything about the tenpin, it's an attraction."),
#  ('Attraction-Inform',
#   'Name',
#   'tenpin',
#   'No its not known by another name and i need information on the address, attraction type and area. Also i need to know the type of Hotel Kirkwood is.'),
#  ('Restaurant-Inform',
#   'Name',
#   'yippee noodle bar',
#   'Yes, please. Can you reserve a table for Friday for 7 people at 13:15?'),
#  ('Hotel-Inform',
#   'Name',
#   'alpha-milton guest house',
#   'Yes please, I need 2 nights for 8 people and we will be arriving on Tuesday.'),
#  ('Restaurant-Inform',
#   'Name',
#   'sesame restaurant and bar',
#   "No, that's okay.  Can I book a table for 2 on friday at 15:15?"),
#  ('Taxi-Inform',
#   'Depart',
#   'downing college',
#   "I'll be going from the attraction to the hotel. I want to leave the attraction by 22:45."),
#  ('Taxi-Inform',
#   'Dest',
#   'worth house',
#   "I'll be going from the attraction to the hotel. I want to leave the attraction by 22:45."),
#  ('Restaurant-Inform',
#   'Name',
#   'little seoul',
#   'Can you book me a table there?'),
#  ('Attraction-Inform',
#   'Name',
#   'club salsa',
#   'Great, could I get the address there please?'),
#  ('Attraction-Inform',
#   'Name',
#   'castle galleries',
#   'Sounds great! Do they have an entrance fee?'),
#  ('Restaurant-Inform',
#   'Food',
#   'swedish',
#   'I want a place that serves Swiss food.'),
#  ('Restaurant-Inform',
#   'Name',
#   'curry prince',
#   'Yes, that sounds good. Please make the reservation for me.  '),
#  ('Restaurant-Inform',
#   'Name',
#   'the cow pizza kitchen and bar',
#   'What is the price range?'),
#  ('Train-Inform',
#   'People',
#   '8',
#   'That sounds great. I would like to book it for 7 people. I will also need the reference number'),
#  ('Hotel-Inform',
#   'Name',
#   'allenbell',
#   'Sounds great, can you book it for 7 people for 4 nights starting saturday?'),
#  ('Hotel-Inform',
#   'Name',
#   'finches bed and breakfast',
#   "Yes please and i'll need the reference number"),
#  ('Taxi-Inform',
#   'Depart',
#   'finches bed and breakfast',
#   'I need to leave the hotel by 8:00 and go to the theatre thank you.'),
#  ('Taxi-Inform',
#   'Dest',
#   'mumford theatre',
#   'I need to leave the hotel by 8:00 and go to the theatre thank you.'),
#  ('Attraction-Inform',
#   'Name',
#   'churchill college',
#   'Yes, I need to book a taxi.'),
#  ('Hotel-Inform',
#   'Name',
#   'the cambridge belfry',
#   'Yes please and make it for wednesday and for 3 days.'),
#  ('Attraction-Inform',
#   'Name',
#   'Scott Polar',
#   'Yes that would be fine. I need the postcode, entrance fee and attraction type.'),
#  ('Attraction-Inform',
#   'Name',
#   'all saints church',
#   'Yes please. How much does it cost? '),
#  ('Hotel-Inform',
#   'Name',
#   'hamilton lodge',
#   'Excellent. Can I book that for 2 people for 2 nights starting on Tuesday'),
#  ('Hotel-Inform',
#   'Type',
#   'guesthouse',
#   "That's too bad. Would you be able to find me a different hotel in the same price range?"),
#  ('Attraction-Inform',
#   'Name',
#   'vue cinema',
#   'awesome, sounds good. What is their postcode please?'),
#  ('Hotel-Inform',
#   'Name',
#   'university arms hotel',
#   'sounds good thanks book it for 6 for 4 nights on wednesday'),
#  ('Taxi-Inform',
#   'Arrive',
#   '13:45',
#   'Two for the same day. I need a taxi to commute between the two places to be sure it arrives by the booked time. The contact number and car type?'),
#  ('Restaurant-Inform', 'Area', "don't care", 'i dont really care.'),
#  ('Hotel-Inform',
#   'Name',
#   'huntingdon marriott hotel',
#   "Can you book it for me for Thursday I'm staying 5 nights. Only one person is staying. "),
#  ('Hotel-Inform',
#   'Stay',
#   '5',
#   'That sounds great can you book a room for 4 people? We are checking in Monday and staying 4 nights. '),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'That sounds great can you book a room for 4 people? We are checking in Monday and staying 4 nights. '),
#  ('Attraction-Inform',
#   'Name',
#   'the man on the moon',
#   'What is the entrance fee there?'),
#  ('Hotel-Inform',
#   'Area',
#   'east',
#   'something that is in the same part of town as the restaurant would be good.'),
#  ('Hotel-Inform', 'Name', 'el shaddai', 'i just want the address for now.'),
#  ('Attraction-Inform',
#   'Name',
#   'cineworld cinema',
#   'Sounds great can I get the address. '),
#  ('Restaurant-Inform',
#   'Name',
#   'galleria',
#   'That sounds good! Could you book it for me? '),
#  ('Attraction-Inform',
#   'Name',
#   'mumford theatre',
#   'Could I get their phone number?'),
#  ('Restaurant-Inform',
#   'Name',
#   'the varsity restaurant',
#   'yes book for 3 people at 19:30 on friday please'),
#  ('Taxi-Inform',
#   'Arrive',
#   '19:30',
#   'Great, I also need a taxi from the attraction to the restaurant and want to arrive by the reservation time.'),
#  ('Restaurant-Inform', 'Name', 'galleria', 'Yes, that would be great.'),
#  ('Hotel-Inform',
#   'Stay',
#   '4',
#   'Yes, what is the reference number?  I also need a train that departs from Cambridge by 12:30 can you assist with that?'),
#  ('Attraction-Inform',
#   'Name',
#   'Castle Galleries',
#   'That sounds good. Can you tell me what the entrance fee is?'),
#  ('Hotel-Inform',
#   'Day',
#   'wednesday',
#   'Yes there will be one guest. I will need the hotel reference number. I also need a train that arrives by 20:30 and leaves on sunday '),
#  ('Attraction-Inform',
#   'Type',
#   'swimmingpool',
#   'I would like to go to a swimming pool.'),
#  ('Restaurant-Inform',
#   'Name',
#   'loch fyne',
#   'Yes please I need it for 6 people for 14:15 on a Wednesday. I will need the reference number.'),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'book it for 7 people and 3 nights starting from sunday.'),
#  ('Attraction-Inform',
#   'Name',
#   'trinity',
#   'Sure, can I have their phone number please?'),
#  ('Taxi-Inform',
#   'Arrive',
#   '14:00',
#   'I need to book a taxi for the commute between the two places.  can you book one for me so I arrive on time?'),
#  ('Attraction-Inform',
#   'Name',
#   'churchill college',
#   'What is the address to Churchhill College?'),
#  ('Restaurant-Inform',
#   'Price',
#   'moderate',
#   'I am looking for an Eastern restaurant, medium price'),
#  ('Restaurant-Inform',
#   'Name',
#   'mahal of cambridge',
#   'Do you have the phone number?'),
#  ('Taxi-Inform',
#   'Depart',
#   'autumn house',
#   'That hotel we discussed earlier. '),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'Yes, I would like to book it for 5 people for 5 nights starting on Friday. Can you give me a reference number?'),
#  ('Hotel-Inform',
#   'Name',
#   'bridge guest house',
#   'Yes for monday. I will be staying one night.'),
#  ('Hotel-Inform',
#   'Name',
#   'acorn guest house',
#   'Yes, I would like to book it for 5 people for 5 nights starting on Friday. Can you give me a reference number?'),
#  ('Train-Inform',
#   'Depart',
#   'cambridge',
#   'Great!  What is the departure time?'),
#  ('Restaurant-Inform',
#   'Name',
#   'the nirala',
#   'Yes, please! I need a table for 2 on Tuesday at 16:15?'),
#  ('Restaurant-Inform',
#   'Name',
#   'saffron brasserie',
#   'No but can I get the phone number, address and postcode please?'),
#  ('Train-Inform',
#   'Depart',
#   'cambridge',
#   "I'm going to bishops stortford after work, after 21:15 would work."),
#  ('Train-Inform',
#   'Day',
#   'sunday',
#   'Great! I will also need a train. I need to leave on Saturday and depart from Cambridge.'),
#  ('Restaurant-Inform',
#   'Name',
#   'the cambridge chop house',
#   'No, I actually do not need any further assistance today. Thank you, goodbye!'),
#  ('Hotel-Inform',
#   'Name',
#   'avalon',
#   'Yes, please. We will be arriving on Saturday and staying 4 nights. There are 6 people in our party.'),
#  ('Hotel-Inform',
#   'Name',
#   'avalon',
#   'Do they offer free parking? If so, I would like to book. '),
#  ('Hotel-Inform',
#   'Name',
#   'archway house',
#   "That's great. Can you give me the area and price range, please?"),
#  ('Hotel-Inform',
#   'Name',
#   'kirkwood house',
#   'Yes please book that for 6 people for 4 nights starting tuesday and give me the reference number on it.'),
#  ('Taxi-Inform',
#   'Leave',
#   '05:45',
#   'Yes, please, I would like a taxi from the restaurant to the guesthouse.'),
#  ('Attraction-Inform',
#   'Name',
#   'broughton house gallery',
#   'yes that sounds good can I get the postcode, address of that place?'),
#  ('Hotel-Inform',
#   'Name',
#   'carolina bed and breakfast',
#   'Ok that sounds perfect please book that for 7 people for 5 nights starting from thursday. '),
#  ('Taxi-Inform',
#   'Dest',
#   'acorn guest house',
#   'I need to leave the attraction by 21:00 please.'),
#  ('Taxi-Inform',
#   'Depart',
#   'acorn guest house',
#   'I will be leaving the hotel by 23:30 to the Cambridge Arts Theatre.'),
#  ('Restaurant-Inform',
#   'Time',
#   '18:30',
#   "You should have booked it last time you just didn't want to so skipped it. "),
#  ('Taxi-Inform',
#   'Car',
#   'yellow volvo ',
#   'Booking completed!\nBooked car type\t:\tyellow volvo\nContact number\t:\t07057945339\n'),
#  ('Taxi-Inform',
#   'Phone',
#   '07057945339 ',
#   'Booking completed!\nBooked car type\t:\tyellow volvo\nContact number\t:\t07057945339\n'),
#  ('Hotel-Inform', 'Name', 'cityroomz', 'Do they have internet?'),
#  ('Restaurant-Inform',
#   'Name',
#   'the varsity restaurant',
#   'Sure is that in the moderate price range?'),
#  ('Restaurant-Inform',
#   'Time',
#   '1430',
#   "If neither restaurant is available for 13:30, can you try 14:30?  It's later than I wished, but I guess that can't be helped. "),
#  ...]

# %%
for k,v in da2usersen.items():
    print(k,'\t',len(v))
    for sen in v[:3]:
        print('\t',sen)
# Out:
# ('Hotel-Inform',) 	 11515
# 	 am looking for a place to to stay that has cheap price range it should be in a type of hotel
# 	 no, i just need to make sure it's cheap. oh, and i need parking
# 	 Yes, please. 6 people 3 nights starting on tuesday.
# ('general-bye',) 	 2714
# 	 No, that will be all. Good bye.
# 	 You were great. Goodbye.
# 	 Thank you very much, goodbye.
# ('Police-Inform',) 	 160
# 	 Hello, I have been robbed.  Can you please help me get in touch with the police?
# 	 Can you tell me the address to the police station in Cambridge?
# 	 Hi, I would like to find Parkside Police Station please.
# ('Police-Request',) 	 181
# 	 Can I please have the postcode as well?
# 	 Was Parkside the address of the police station? If not, can I have the address please?
# 	 I need the address including postcode of the police station and also the phone number.
# ('general-thank',) 	 9026
# 	 Thank you that will be all for now.
# 	 Thank you for all the help! I appreciate it.
# 	 Thank you. That's all I needed.
# () 	 7091
# 	 Could you book the Wartworth for one night, 1 person?
# 	 That sounds great, could you make a booking for me please?
# 	 I was robbed a few minutes ago and need assistance.
# ('Hotel-Inform', 'Hotel-Request') 	 773
# 	 Friday and Can you book it for me and get a reference number ?
# 	 Just a guesthouse in the north with free parking. I'll need a reference number then too please.
# 	 5 nights please. And I would need the reference number also.
# ('Train-Inform',) 	 10207
# 	 I am looking to book a train that is leaving from Cambridge to Bishops Stortford on Friday.
# 	 I want to get there by 19:45 at the latest.
# 	 Hi, I'm looking for a train that is going to cambridge and arriving there by 20:45, is there anything like that?
# ('Train-Request',) 	 1529
# 	 Yes please. I also need the travel time, departure time, and price.
# 	 What is the price of the fair and could you tell me what is the arrival time into Peterborough?
# 	 Yes, please. Could I have the reference number as well?
# ('Taxi-Inform',) 	 2452
# 	 I would like a taxi from Saint John's college to Pizza Hut Fen Ditton.
# 	 I want to leave after 17:15.
# 	 I'll need a ride there. Can you arrange a taxi for me?
# ('Hotel-Request',) 	 1313
# 	 Okay, none of them DON'T offer free wifi? If not, I'll need the address for one that does have wifi, please. Tell me about your favorite.
# 	 Please book it and provide the reference number.
# 	 I don't need to book today, thanks. Can you get me the postcode of one of them? Oh, and please make sure the one you choose has internet!
# ('Train-Inform', 'Train-Request') 	 742
# 	 I don't need anything booked.  I just need to get the arrival time, travel time and price of a train from norwich to cambridge leaving after 21:15.
# 	 the train should arrive by 13:45 and book for 6 people and give me the reference number please
# 	 Just one.  Can I get the reference number for that?
# ('Attraction-Inform',) 	 4118
# 	 I am planning a trip to town and want to sight see a bit. Can you let me know some attractions I may be interested in?
# 	 I'd like something in the centre.
# 	 I was hoping to see local places while in cambridge. Some entertainment would be great.
# ('Attraction-Request',) 	 2450
# 	 Could I get the address for it? I would also like an expensive place to eat around it.
# 	 It doesn't matter.  Can I have the address of a good one?
# 	 Okay, may I have their postcode, entrance fee, and phone number?
# ('Restaurant-Inform',) 	 10970
# 	 I'm in the mood for Caribbean food.
# 	 Yes, I need a restuarant. I want something on the south side. Expensive.
# 	 Indian food is my favorite! What's the address for the best one?
# ('Attraction-Inform', 'Restaurant-Inform', 'Attraction-Request') 	 13
# 	 Yes, I also love turkish food. Is there something in the center that's expensive? Also, what type of attraction is All Saints Church?
# 	 Cambridge Arts sounds good, can I get the phone number? Is there any entrance fee? And then a nice expensive dinner in the same area please.
# 	 I want to try Scudamores Punting Co. What is their postcode and phone number, please?
# ('Restaurant-Inform', 'Restaurant-Request') 	 886
# 	 Can I have the phone number, address and postcode for the restaurant please?
# 	 How about 10:30 on sunday? And may I have a reference number?
# 	 Yes, table for 2 at 13:30 on Friday. If not available then Tuesday. Need reference number as well.
# ('Hospital-Inform',) 	 314
# 	 I've been injured and need to find a hospital nearby.
# 	 I am looking in town  for a hospital with a paediatric clinic
# 	 Where's the closest hospital with a paediatric intensive care unit?
# ('Hospital-Request',) 	 252
# 	 No, I just need the general phone number, please.
# 	 I need the address and phone number and postal code
# 	 Can I get the postcode as well?
# ('Attraction-Inform', 'Attraction-Request') 	 1038
# 	 I am also looking for a museum in centre. Could you give me the address, postcode and phone number of one?
# 	 Could i also get the phone number and postcode?
# 	 Can I please get their phone number and postcode?
# ('Restaurant-Request',) 	 1726
# 	 Thank you. May I have the address?
# 	 Can I get the postcode, price range, and phone number of one?
# 	 Yes, may I have the address?
# ('Attraction-Inform', 'Train-Inform') 	 17
# 	 Just one, please. I'm also looking for colleges in the centre of town.
# 	 Let's forget about the attraction for now.  Can you help me with a train?
# 	 I am looking for the Cambridge Book and Print Gallery
# ('Train-Inform', 'Restaurant-Inform') 	 64
# 	 Thank you so much. The restaurant and train are all I need for now. Have a great day. Goodbye.
# 	 The same day as the train which is Monday.
# 	 Yes please. I am also looking for a place to eat. Are there any restaurants in East Cambridge that serve unusual foods?
# ('Taxi-Inform', 'Restaurant-Inform') 	 324
# 	 Will the taxi arrive to the restaurant by the booked time?
# 	 I also need to book a taxi between the restaurant and the church.
# 	 I need a taxi. I want to be taken from the hotel to nandos city centre, arriving by 17:00. Please give me the car and contact information
# ('Restaurant-Inform', 'Taxi-Request') 	 7
# 	 thank you, I hope its in the expensive price range. and if you could give me the phone number that would be great
# 	 As I just said, at the restaurant by 18:30.   Can I please get the car type and reference number?
# 	 Preferably in the east. Would like the phone number. Also looking for colleges to visit and need to book a taxi for 1:15. I will need the number and car type.
# ('Taxi-Inform', 'Taxi-Request') 	 160
# 	 i also want to book a taxi to leave the attraction by 08:00. get contact number and car type
# 	 My destination is kettle's yard, and anytime after 8:15 would be fine. Please notify me of the car type and the contact number. Thank you.
# 	 Yes I'd like to book a taxi from the hotel to the nightclub and i need to leave by 22:15.And may i have car type and confirmation # please?
# ('Restaurant-Inform', 'Attraction-Request') 	 46
# 	 Yes, what is the entrance fee and could you find me a restaurant in the moderate price range located in the centre town?
# 	 maybe if you can get me the address. i also  want a restaurant in the same place which serves indian food.
# 	 What type of restaurants are located in the city centre?
# ('Hotel-Inform', 'Attraction-Request') 	 51
# 	 I need the address and entrance fee as well. Also can you help me find a hotel with free parking in the moderate price range?
# 	 I'm not concerned about the area, but I'd like it to include free parking and wifi and have a 3 star rating please.
# 	 No preference on the area or price range, but the hotel should have 4 stars.
# ('Hotel-Inform', 'Train-Request') 	 143
# 	 I looking for information about a hotel in the moderate price range that includes free wifi.
# 	 Sure, Can I have a reference Number?
# 	 Again, 3 star with free wifi. I don't care about the price. It has to be in the centre, though.
# ('Hotel-Inform', 'Restaurant-Inform') 	 140
# 	 Thanks, I also need a restaurant in the Centre that serves European food. It needs to be in the same price range as hotel.
# 	 Thank you. Are there any cheap restaurants near the hotel as well?
# 	 the hotel to the restaurant please
# ('Taxi-Inform', 'Hotel-Inform') 	 133
# 	 From the hotel.  I would like to get a contact number for the taxi also, just in case something changes.
# 	 I will need to be picked up at the hotel by 4:45 to arrive at the college on tuesday.
# 	 Yes, could you book a taxi for me?  I'd like to leave The Gonville Hotel by 24:00, going to All Saints Church.
# ('Restaurant-Inform', 'Train-Request') 	 105
# 	 Are there any that are in the expensive price range?
# 	 Thanks.  I also need to find a place to dine.  I'm looking for something moderate in price and in the west.
# 	 Yes, I would like it the same day at 14:00. I would also like the reference number from the train and restaurant please.
# ('Taxi-Request',) 	 132
# 	 Yes I would like a contact number and car type please for my booking.
# 	 I need a cab by 12:30 too the contact # and car type will be most helpful
# 	 It would be nice if you would tell me the car type and it's contact number.
# ('Hotel-Inform', 'Attraction-Inform') 	 34
# 	 Actually, I'm looking for an attraction in the area of the hotel.
# 	 attraction to the hotel, by 9:30
# 	 Can we also look at hotels in the same area as the attraction?
# ('Attraction-Inform', 'Restaurant-Request') 	 17
# 	 Thank you for the reference number.  I'm also looking for places to go in the south side of town.
# 	 I need the phone number and postcode for Cote and I am looking for an attraction called Clare Hall.
# 	 I'm here to visit some colleges, can you please help me find the addresses of some of them?
# ('Hotel-Inform', 'Train-Inform', 'Hotel-Request') 	 5
# 	 The hotel booking is for 4 people starting Monday. We will stay 2 nights. I need the train from Norwich to arrive in Cambridge by 15:15. Please provide reference numbers.
# 	 Yes, I would.  I need 3 nights, 7 people, starting Wednedady.  I need the reference number.  I also need a train to Cambridge after 14:45.
# 	 Can you try booking a 1 night stay? I need the reference number if that works. I also need a train leaving Cambridge after 17:45, arriving in Norwich on Wednesday.
# ('Taxi-Request', 'Attraction-Request') 	 16
# 	 The would be great. Can I have the address and phone number?
# 	 I also need a cab by the booked time, contact number and car type please
# 	 restaurant is what i am looking for, entrance fee and postcode please. get me a taxi from the attraction by 10.15, get me its contact number and car type.
# ('Attraction-Request', 'Restaurant-Request') 	 11
# 	 I am not sure how many people will be coming, so I will do that later. But can you provide me with their postcode and phone number?
# 	 Great, would you happen to know there address along with postcode? Do you have there phone number as well?
# 	 And what's the post code that goes with that address?
# ('Attraction-Inform', 'Restaurant-Inform') 	 45
# 	 Not right now, I am also looking for an expensive Italian restaurant in the same area as the attraction.
# 	 Not at the moment. Can you also look up the attractions near the restaurant as well?
# 	 In the same area as Cambridge Artworks.
# ('Restaurant-Inform', 'Hotel-Request') 	 41
# 	 I'm looking for something in the moderate price range.  I think asian oriental sounds good.
# 	 Thanks.  I am also looking for a place to eat in that same area, same price range as well.
# 	 I would like somewhere moderately priced.
# ('Taxi-Inform', 'Hotel-Inform', 'Restaurant-Inform') 	 78
# 	 OK, I also want to book a taxi between the hotel and restaurant.
# 	 Thank you. I also need a taxi two commute between the hotel and restaurant.
# 	 I would like to book a taxi from the hotel to the restaurant, one that gets me there in time for my reservation.
# ('Hospital-Inform', 'Hospital-Request') 	 8
# 	 I need the address of the hospital and the phone number of the transplant high dependency unit department, please.
# 	 Do they have a transitional care department? I would also like to know the postcode and phone number.
# 	 I need the emergency department. Could I also get the postcode?
# ('Hotel-Request', 'Attraction-Request') 	 4
# 	 Could I get the phone number and address of one of them?  Also can you find me a nightclub nearby and give me their postcode?
# 	 That sounds great!! Can I have their address, and how much is the entrance fee?
# 	 No thank you, could I have the address with postcode and phone number?
# ('general-greet',) 	 45
# 	 Hello. I am coming into town and would like help finding a play to stay.
# 	 Hello. I'm looking for a place to dine tonight. I wouldn't like anything expensive, and I'd prefer something in the city center.
# 	 Hello, I am looking for a guest house.
# ('Taxi-Inform', 'Restaurant-Inform', 'Taxi-Request') 	 25
# 	 Yes, I need a taxi to take me from the hotel you just booked to Fitzbillies restaurant, arriving by 13:30. Please give me a car type and contact info
# 	 Yes I would like a taxi to arrive at the restaurant by 17:00. I would need the phone number and the type of car.
# 	 I would like a taxi from the hotel to the restaurant. I would like to arrive by 14:45. I would like the contact number and car type.
# ('Hotel-Inform', 'Attraction-Inform', 'Attraction-Request') 	 6
# 	 Yes. What is the postcode and phone number? Also, I am needing a 4 star hotel in the same area. Can you check if one is available for me?
# 	 Can you find a museum that is close to my hotel? I would like to know the entry fee, address and phone number. Thank you.
# 	 please get me the postcode. I am also looking for a place to stay. The hotel should be in the cheap price range and should include free parking.
# ('Taxi-Inform', 'Attraction-Inform', 'Taxi-Request', 'Attraction-Request') 	 1
# 	 Okay, please provide me with the postcode, and also I want a taxi to take me there. It should leave the hotel by 10:30. Give me car type and contact number
# ('Taxi-Inform', 'Attraction-Inform') 	 15
# 	 Yes, I will need to book a taxi to transport me to the attraction.
# 	 Lastly, I need a taxi from the park to the restaurant, we plan to leave the park at 10:30.
# 	 Oh, yeah, I do want information on attractions! In the same area. After that, I will need a taxi.
# ('Train-Inform', 'Attraction-Request') 	 27
# 	 I am departing from birmingham new street. Oh, I also need the address for the swimmingpool. You mentioned parkside pools in the centre. Their address?
# 	 Please do give me the address and also if you could I am looking for a train as well to depart from cambridge and head down to london liverpool street.
# 	 That's okay, could you provide me with the postcode and address, please? Also, I am looking for a train leaving after 16:00 this Monday.
# ('Attraction-Inform', 'Train-Inform', 'Attraction-Request') 	 9
# 	 whats its postcode and address? i would also like to get a train that leaves friday from kings lynn
# 	 I'd like to arrive at Leicester by 17:45.  And what was that postcode for Whale of a Time again?
# 	 I will need to know the entrance fee as well.  Once I get that I also need help finding a train leaving Cambridge to kings lynn after 16:45.
# ('Attraction-Inform', 'Hotel-Request') 	 15
# 	 Can you please give me the address and phone number of the location? I would also like to find some college-related attractions in that area.
# 	 Do you have any places to go in the east area?
# 	 What is the price range of the Carolina Bed and Breakfast?
# ('Taxi-Inform', 'Attraction-Inform', 'Taxi-Request') 	 1
# 	 I'd like to book a taxi leaving the hotel by 21:00.  I'd also like the contact number and car type.
# ('Hotel-Inform', 'Restaurant-Request') 	 28
# 	 Yes please book for 7 people and 5 nights starting from wednesday. What is their address and phone number.
# 	 Thank you. Can you give me a reference number? Also, I need to book a 4 star guesthouse.
# 	 Still deciding that part but would definitely need the expensive price range.
# ('Taxi-Inform', 'Hotel-Inform', 'Taxi-Request') 	 11
# 	 Please have the taxi pick me up at the hotel. Can I get the taxi contact number and car type?
# 	 Two for the same day. I need a taxi to commute between the two places to be sure it arrives by the booked time. The contact number and car type?
# 	 I'll just need a taxi from the restaurant at 9:00 to the hotel .  Can you provide their contact number and the car type?
# ('Hotel-Request', 'Restaurant-Request') 	 3
# 	 i want to know the food type and area
# 	 If Saturday fails, try Monday and provide the reference number. Also looking for a guesthouse in the same area with internet. Provide starts and address please.
# 	 Pick the most popular one,  I need their phone number as well and hotel type. If they have area and postal code , I will need it.
# ('Hotel-Inform', 'Taxi-Request') 	 12
# 	 I'd like to leave the hotel by 6:45.  Once that is booked can you provide me with the phone number and car type?
# 	 Yes also I will need a taxi to get me between the hotel and the restaurant. I will need a contact number and car type with the booking.
# 	 Yes I also need to book a taxi to take us between the hotel and the restaurant. I will need the car type and a contact number for the booking.
# ('Train-Inform', 'Restaurant-Inform', 'Restaurant-Request') 	 7
# 	 Can I have their phone number and address? Also, are there any trains that go from Peterborough to Cambridge?
# 	 I need the reference number for the booking. Also can you help me find a train going to Cambridge Wednesday?
# 	 The expensive range please.  I will need their phone number and address.  Also, I am looking for a train departing from Cambridge on Saturday.
# ('Hotel-Inform', 'Train-Inform') 	 44
# 	 I need a train that leaves Cambridge on Wednesday to arrive in Leicester by 12:15 please.
# 	 That's okay. Can you tell me about a hotel though? It's the Express by Holiday Inn Cambridge.
# 	 I think that is it, got bookings for hotel and train.
# ('Taxi-Inform', 'Taxi-Request', 'Attraction-Request') 	 14
# 	 Okay well now I need to get a taxi to leave the hotel by 17:45 to the attraction. I will need a contact number and car type.
# 	 Yes, please book a taxi for me. I want to leave at 19:30 from my hotel and go to Cambridge artworks. Please give me the car type and contact info
# 	 Yes, I need the entrance fee.  I will also need a taxi to pick me up by 24:30.  I need the contact number and car type please.
# ('Hotel-Inform', 'Restaurant-Inform', 'Hotel-Request') 	 11
# 	 I want chinese food in cheap price range in west side of town. A 3 star hotel that is expensive and includes wifi. Also the hotel address, area, and postcode please.
# 	 Lets see what is available cheap, same area as the restaurant makes most sense but i am open to any area.
# 	 Sorry I have the restaurant. I am looking for a cheap, four star hotel with free parking and internet.
# ('Hotel-Inform', 'Restaurant-Inform', 'Restaurant-Request') 	 11
# 	 In the same area as the restaurant, centre.  In prefer a cheap price range.
# 	 There will be 8 of us and I am also looking for a moderate priced restaurant in the center for 11;15 on Saturday.  Please send me the reference number.
# 	 Can I please have the phone number and area for Pizza Hut Fen Ditton? Also, the guesthouse we booked is 4 stars correct?
# ('Taxi-Inform', 'Hotel-Inform', 'Taxi-Request', 'Hotel-Request') 	 1
# 	 Yes, I also need postcode, the area of the hotel and leave the restaurant by 20:15. I need a taxi to commute between both, the contact number and car type.
# ('Attraction-Inform', 'Taxi-Request') 	 2
# 	 Yes, I would also like to get a taxi too. I would like to know the contact number and car type also.
# 	 I'd like information of cambridge museum of technology.  What is their phone number please?
# ('Taxi-Request', 'Restaurant-Request') 	 2
# 	 Ok that will have to do then.  Please give me the reference number and have the taxi commute between both places, car type and contact info please.
# 	 But that's the reference number for my restaurant reservation. Please confirm my taxi booking! I'll need a contact number and car type so I can make sure it was absolutely completed!
# ('Taxi-Inform', 'Restaurant-Request') 	 2
# 	 First, may I have the address for the rajmahal restaurant? Then, I want to get from the hotel to the restaurant, please.
# 	 Yes please. I also need to postcode. I need to book a taxi from the restaurant to the museum. I'd like to leave the restaurant by 17:30.
# ('Train-Inform', 'Hotel-Request') 	 8
# 	 Please, book the Holiday Inn Cambridge, and I need the reference number. Also, I am looking to book a train the same day from Birmingham new street  to Cambridge leaving after 18:30.
# 	 Is that the correct area? And I also need a train going to cambridge, it needs to leave after 12:30. It should leave wednesday and depart from bishops stortford
# 	 Can I please get the reference number and I also need to book a train for Tuesday.
# ('Taxi-Inform', 'Taxi-Request', 'Hotel-Request') 	 9
# 	 Thanks, I also need a taxi to go the hotel. I want to leave the Man on the moon at 16:15. Can you get me the contact number and car type?
# 	 Thanks. Now I just need a taxi to pick me up at 22:00 from the Huntingdon Marriott and take me to Clare Hall. I'll need car type and contact number
# 	 I'd like to book a taxi to commute between the two places. I want to leave Old Schools by 23:15. Please send the contact number and car type. Thanks!
# ('Attraction-Inform', 'Train-Request') 	 7
# 	 Yes I need the price.  Also, I am traveling in the east, can you recommend a good place to go?
# 	 And the travel time? I also need a museum to go to in the east.
# 	 Can I have the reference number please?  I'm also looking for some places to go, maybe a college in the west.
# ('Attraction-Inform', 'Train-Inform', 'Train-Request') 	 3
# 	 That's perfect please make a booking for 5 and then let me have the reference number. Also can you help me find an architecture attraction?
# 	 Just one.  May I have the reference number for that?  I would also like information for visiting a park in the town center.
# 	 Yes I'd like to book for 2 and need the reference number. I'm also looking for attractions in the centre, anything to do with multiple sports.
# ('Attraction-Inform', 'Restaurant-Inform', 'Restaurant-Request') 	 6
# 	 Please book a table for 2 at 19:15 on Saturday with a reference number and l need a theatre in the same area as the restaurant.
# 	 Yes, please book a table for 2 on Sunday at 19:45. You'll need to give me the reference number. I'm also looking for a nightclub in the center of town.
# 	 On second thought, I need a reservation for 5 at 12:15 on Sunday and the reference number. Also information on a place called Vue Cinema.
# ('Hotel-Inform', 'Attraction-Inform', 'Hotel-Request') 	 2
# 	 Yes, book it and I need a reference number.  It doesn't matter the kind of museum.
# 	 3 nights starting on Saturday, can I get the reference number as well? We are also looking for an attraction called Camboats, can you help me?
# ('Attraction-Request', 'Train-Request') 	 6
# 	 I need one. Departure time, travel time and train ID?  Also, I need a college in the west.  I need the phone number and postcode to it.
# 	 I was first wondering the price of that train and what time it arrived. Oh! I also forgot to ask for the postcode of the Gallery!
# 	 That sounds like a good idea. Could you please give me the phone number and postcode of one you would suggest? Also the attraction's entrance fee.
# ('Train-Inform', 'Restaurant-Request') 	 13
# 	 Is Milton Road Chesterton the full address for Hakka?  I also need a train to cambridge.
# 	 I just need the phone number and post code please?  Can you also help me book a train from Bishops Stortford to Cambridge on Saturday arriving before 15:15?
# 	 Can I have the address? I am also looking for a train that leaves on Sunday to Cambridge.
# ('Taxi-Inform', 'Attraction-Request') 	 2
# 	 I would like to leave my hotel by 22:00.  Would you mind getting the college address for me?
# 	 Thank You!, I will need to book a taxi that can depart by 12:30, please provide me with contact and the type of car.
# ('Taxi-Inform', 'Restaurant-Inform', 'Taxi-Request', 'Attraction-Request') 	 3
# 	 I am also looking for taxi to take from the museum to the restaurant by 11:15. Can you give me a contact number and the car type?
# 	 I would also like to book a taxi that arrives by 12:45 to the restaurant. I would also like its contact number and car type.
# 	 I need it to arrive before the 13:30 at the restaurant.  Can you give me a contact number and the car type that will pick me up?
# ('Taxi-Inform', 'Attraction-Inform', 'Restaurant-Inform') 	 4
# 	 Thanks. I will need a taxi to get from the church attraction to the restaurant, please.
# 	 I will also need a taxi to get from the attraction to restaurant.
# 	 Yes, I'd like to book a taxi to go from the attraction to the restaurant.
# ('Restaurant-Inform', 'Train-Request', 'Restaurant-Request') 	 4
# 	 Is the restaurant moderately priced? If so, please book a table for 5 at 18:00 and send me the reference number.
# 	 Moderate price in the East. and I need the phone number, address, and food type
# 	 Ok, I'll have to speak with my friend to see if that price is acceptable.  Can I please get the address to the restaurant Hotel Du Vin and Bistro?
# ('Taxi-Inform', 'Attraction-Inform', 'Attraction-Request') 	 1
# 	 Sounds great, I need their postal can I also book a taxi from the attraction to the hotel at 01:15
# ('Hotel-Inform', 'Hotel-Request', 'Train-Request') 	 4
# 	 I still need the price and travel time for train TR2694. For the guesthouse, I need the address and number of stars for a moderate guesthouse with wifi and parking.
# 	 I was still needing the address and number of stars for a moderately priced guesthouse with free wifi and parking.
# 	 Do you have free parking? I refuse to pay for parking in a hotel that I am staying at. Wouldn't you agree?
# ('Hotel-Inform', 'Train-Inform', 'Train-Request') 	 6
# 	 What time does that train leave Cambridge? I also need a place to stay in Ely, with free parking and free wifi?
# 	 Yes, I need three tickets and a reference number, and I would also need a guesthouse with free parking.
# 	 Yes I need to inquire about a train from Peterborough to Cambridge for Thursday. I need the travel time, departure time and price. Arriving by 13:00.
# ('Taxi-Inform', 'Restaurant-Inform', 'Restaurant-Request') 	 3
# 	 That's fine. Could you book a table for 8 people at 11:15. I need a reference number. I also need a taxi between both places arriving at the booked time.
# 	 make the reservation for saturday night for 3 people. can I have the full address? book a taxi to leave at 23:30 with contact info
# 	 Make a reservation for 3 people at 11:30 on tuesday, a taxi to commute between the two places by the booked time. I need reference number, contact number and care type.
# ('Attraction-Inform', 'Hotel-Request', 'Attraction-Request') 	 4
# 	 No its not known by another name and i need information on the address, attraction type and area. Also i need to know the type of Hotel Kirkwood is.
# 	 No not really. Can you recommend me an attraction that's in the centre area? Can I also get the address, entrance fee, and phone number for it? Thanks!
# 	 Any attraction in the west is fine.  Im new to the area, so anything that you recommend.  I'll need to phoen and address of whatever you select.
# ('Taxi-Inform', 'Hospital-Inform') 	 3
# 	 Can you please call a taxi to take me to the hospital?
# 	 Can you please book a taxi to take me to the hospital? I am not able to get there on my own.
# 	 Yes, I need a taxi to take me to the Addenbrookes Hospital.
# ('Train-Inform', 'Restaurant-Inform', 'Train-Request') 	 1
# 	 Yes please book for 8 people. I need the reference number. Also, I want information on a restaurant called Bangkok City.
# ('Taxi-Inform', 'Train-Inform') 	 3
# 	 Actually, I do need a taxi to get to the train station. Can you look one up for me?
# 	 Yes, I would like a taxi to the Town Centre. From the train station.
# 	 I'm sorry, did I say Taxi? I mean train.
# ('Taxi-Inform', 'Hotel-Inform', 'Restaurant-Inform', 'Taxi-Request') 	 1
# 	 Yes, for 8 staying 5 nights starting Monday, provide reference number. Also, book a taxi from hotel to arrive at restaurant by 11:45. I will need contact number and car type.
# ('Taxi-Request', 'Hotel-Request') 	 7
# 	 I would like to book a taxi that can commute to both places, It would need to arrive by the booked time. Please provide contact and the car type.
# 	 Yes, please also give me its contact number and the car type.
# 	 How many stars, also the postcode and address? I will also need a taxi and want it to arrive by 17:00. Contact number and car type.
# ('Restaurant-Inform', 'Taxi-Request', 'Restaurant-Request') 	 3
# 	 Yes please and may I have the address and phone number. I would also like to book a taxi to get to the restaurant.
# 	 I would like the address and phone number to De Luca Cucina and Bar. Also looking for places to visit in the same area.
# 	 No, I just need the address and phone number.
# ('Attraction-Inform', 'Attraction-Request', 'Restaurant-Request') 	 4
# 	 Pick the best one and provide the address, number and postcode.
# 	 Could I get the reference number? Also looking for place to go in town. What museum do you recommend? Please send address.
# 	 The Galleria is the name of the restaurant. I need the address for it please. I also need the postcode for the college.
# ('Taxi-Inform', 'Restaurant-Inform', 'Taxi-Request', 'Hotel-Request') 	 3
# 	 Thanks, now can you book me a taxi? I want to be picked up from my hotel and taken to the restaurant by 17:30. Please give me car type/contact number
# 	 Is 14:00 available? I also want to take a taxi to get there. Can you give me a car type and their number?
# 	 I need it to pick me up in time to get me to the restaurant before 11:30.  Can I get a contact number and car type please?
# ('Taxi-Inform', 'Restaurant-Inform', 'Taxi-Request', 'Restaurant-Request') 	 3
# 	 Yes, for 7 people at 16:45 on Monday. I need a reference number. I need a taxi to commute also a place to visit as well as car type
# 	 Book table for 3 saturday at 19:30 and need reference number. I want a taxi to go between the guesthouse and restaurant in time for reservation. Contact number & car type?
# 	 Yes, I need it for Friday, 20:00, for 7 people.  I need a reference number.  I need a taxi betweentwo places before 20:00.  Contact # and car type?
# ('Hotel-Inform', 'Hotel-Request', 'Attraction-Request') 	 2
# 	 What is the address and post code?
# 	 Oh thank you for the name of the museum and what part of the area is this museum in?  I'd also like information about the Lensfield Hotel.
# ('Taxi-Inform', 'Hotel-Inform', 'Taxi-Request', 'Hotel-Request', 'Attraction-Request') 	 1
# 	 Yes, one person, 4 nights starting Wednesday. Reference number for that, parks to visit. Area, address and phone number and a taxi to arrive at 17:00, contact number and car type.
# ('Taxi-Inform', 'Hotel-Inform', 'Attraction-Inform') 	 4
# 	 I need a taxi from the hotel to the attraction, leaving at 2:45.
# 	 I will also need a taxi to get to the attraction by 6:30 from my hotel.
# 	 Thanks, again. Finally, I need a taxi between the hotel and the Old School attraction, please.
# ('Hotel-Inform', 'Taxi-Request', 'Hotel-Request') 	 2
# 	 Yes that would be fine.   I have another request,  I would like the address and phone number of the University Arms Hotel.
# 	 Monday, for 2 nights, 2 people.  I'll need a reference number.  Also, I need a taxi to college by 4:00.  I need the contact number and car type.
# ('Train-Request', 'Restaurant-Request') 	 1
# 	 Yes please. I will also need the reference number and price.
# ('Hotel-Request', 'Train-Request') 	 1
# 	 A moderate priced one is fine. Please give me the postcode phone number and area.
# ('Attraction-Inform', 'Taxi-Request', 'Attraction-Request') 	 3
# 	 Yes, may I please have their address and phone number.
# 	 I need to visit an attraction type college near the restaurant, give me the entrance fee and phone number. Also, I need a taxi, will need the phone and car type.
# 	 Yes, the type of concert hall. I need address and a taxi for 11 and the car type and contact number please
# ('Taxi-Inform', 'Restaurant-Inform', 'Attraction-Request') 	 1
# 	 I would like the taxi arrives at the restaurant by 13:30. Also could you provide me with the phone number for Castle Galleries?
# ('Attraction-Inform', 'Restaurant-Inform', 'Attraction-Request', 'Restaurant-Request') 	 1
# 	 Could I get the postcode for that museum? I am also looking for a restaurant called peking restaurant. What area that is in, the address, and postcode?
# ('Train-Inform', 'Hotel-Request', 'Train-Request') 	 2
# 	 I want to leave at 19:30 and need two tickets. Please send me the reference number and telephone number to the train company.
# 	 I need to book for one person, I will need the reference number. Also, I need to book a hotel called Caroline Bed and Breakfast, I need the address.
# ('Police-Inform', 'Hospital-Inform') 	 1
# 	 I was just in a car accident and I need the police to come to the scene. I also need to know where the closest hospital is.
# ('Restaurant-Inform', 'Hotel-Request', 'Restaurant-Request') 	 2
# 	 Is that restaurant in the centre area and could I get the postcode please?
# 	 I am not quite ready to book a table, but may I have the address of the restaurant including the postcode and the phone number?
# ('Taxi-Inform', 'Taxi-Request', 'Hotel-Request', 'Restaurant-Request') 	 1
# 	 I need the address and postcode.  I need a taxi to pick me up at the hotel by 19:00.  I need the contact number and car type please.
# ('Hotel-Inform', 'Taxi-Request', 'Attraction-Request') 	 1
# 	 Could I just have the phone number and address?
# ('Taxi-Inform', 'Hotel-Inform', 'Hotel-Request') 	 1
# 	 Can you confirm the area of that hotel?  I also need a taxi to go from the hotel to Bedouin, I will need to arrive by 18:00.
# ('Taxi-Inform', 'Hotel-Inform', 'Attraction-Inform', 'Restaurant-Inform') 	 1
# 	 I'm looking for a family friendly restaurant that is reasonably price and located in the center of town near attractions, hotels and easy access to transportation such as buses and taxis.
# ('Taxi-Inform', 'Hotel-Request') 	 1
# 	 Whatever hotel you booked me at. The reference number is: GXQZCBL8
# ('Attraction-Inform', 'Train-Inform', 'Attraction-Request', 'Train-Request') 	 1
# 	 I need 5 tickets and the reference number. I would like to go to a museum attraction in town. Please provide a area, phone number, and postcode.  Thank you.
# ('Hotel-Inform', 'Hotel-Request', 'Restaurant-Request') 	 1
# 	 Great, can I get their postcode, address, and phone number?
# ('Taxi-Inform', 'Restaurant-Inform', 'Taxi-Request', 'Attraction-Request', 'Restaurant-Request') 	 1
# 	 Reservation for 3 at 13:00 on Saturday at the Ugly Duckling. Please provide reference number. Book a taxi to arrive before the booked time. Phone number and car type.
# ('Taxi-Inform', 'Taxi-Request', 'Restaurant-Request') 	 1
# 	 What's the address and postcode for Graffiti?  Could you also book a taxi from the hotel at 20:15? Please send me the contact number and car type.
# ('Attraction-Inform', 'Attraction-Request', 'Train-Request') 	 1
# 	 Do you have any boating attractions that do list their entrance fees? I want to make sure I have enough cash with me when I arrive.

# %%
145665/149890
# Out:
# 0.9718126626192541

# %%
sum([142535, 1428, 1002, 285, 358, 57])
# Out:
# 145665

# %%
json.dump(all_data,open('annotated_user_da_with_span_full.json','w'),indent=4)

# %%
json.dump(dict(list(all_data.items())[:100]),open('annotated_user_da_with_span_100sample.json','w'),indent=4)

# %%
json.dump(no_span_sentence,open('no_span_sentence.json','w'),indent=4)

# %%
149890-145665
# Out:
# 4225
